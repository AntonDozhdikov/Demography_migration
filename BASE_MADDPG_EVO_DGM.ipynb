# %% [markdown]
# <a href="https://colab.research.google.com/github/AntonDozhdikov/Demography_migration/blob/main/BASE_MADDPG_EVO_DGM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
""" BASE EXP 1000 ep. MADDPG_baseline, MADDPG_EVO, MADDPG_EVO_DGM
"""
# -*- coding: utf-8 -*-
"""
MADDPG CORE - Fixed Version 1.1
File 1/3: Basic Components and Algorithms
FIXED: imports, compatibility, stability, common reward function, improved DGM module
"""
import os
import math
import time
import json
import random
import warnings
import copy
from datetime import datetime
from collections import deque, defaultdict
from typing import Dict, List, Tuple, Optional, Union, Any
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
# Fixed tqdm import for Google Colab
try:
    from tqdm.auto import tqdm
except ImportError:
    try:
        from tqdm import tqdm
    except ImportError:
        # Fallback for cases where tqdm is unavailable
        def tqdm(iterable, *args, **kwargs):
            desc = kwargs.get('desc', '')
            total = len(iterable) if hasattr(iterable, '__len__') else None
            for i, item in enumerate(iterable):
                if desc and total:
                    if i % max(1, total // 20) == 0:
                        print(f"{desc}: {i+1}/{total}")
                yield item
warnings.filterwarnings('ignore')
# Settings for reproducibility
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
print("🚀 MADDPG CORE V1.1 - FIXED VERSION")
print(f"📱 Device: {DEVICE}")
print(f"🎯 Seed: {SEED}")
# ===== CONFIGURATION =====
CONFIG = {
    'training_epochs': 1000,
    'testing_epochs': 200,
    'region_addition_phase': 600,
    'total_regions': 86,
    'batch_size': 32,
    'episode_length': 15,
    'buffer_size': 50000,
    'log_interval': 10,
    'milestone_interval': 10,
}
# ===== COMMON (STARTING) REWARD FUNCTION =====
REWARD_WEIGHTS = {
    'population': 2.0,
    'natural_increase_rate': 3.0,
    'birth_rate': 2.5,
    'death_rate': -2.0,
    'migration_balance': 2.2,
    'gdp_per_capita': 1.8,
    'average_wage': 1.5,
    'unemployment_rate': -1.8,
    'stability_bonus': 1.0
}
def calculate_honest_reward(region_data: dict, actions: np.ndarray = None) -> float:
    """
    Common reward function for all algorithm participants in the experiment
    Based solely on demographic and economic metrics
    """
    if not region_data:
        return 0.0
    reward = 0.0
    # Basic components
    base_components = ['population', 'natural_increase_rate', 'birth_rate',
                      'death_rate', 'migration_balance', 'gdp_per_capita',
                      'average_wage', 'unemployment_rate']
    for component in base_components:
        if component in region_data:
            value = float(region_data[component])
            if not np.isnan(value) and not np.isinf(value):
                weight = REWARD_WEIGHTS.get(component, 0)
                reward += weight * np.clip(value, -3.0, 3.0)
    # Dynamic components (changes)
    delta_weights = {
        'delta_population': 1.5,
        'delta_birth_rate': 2.0,
        'delta_gdp_per_capita': 1.8,
        'delta_migration_balance': 1.6,
        'delta_average_wage': 1.2
    }
    for delta_key, weight in delta_weights.items():
        if delta_key in region_data:
            delta_value = float(region_data[delta_key])
            if not np.isnan(delta_value) and not np.isinf(delta_value):
                reward += weight * np.clip(delta_value, -1.0, 1.0)
    # Stability bonus
    if 'delta_population' in region_data:
        delta_pop = float(region_data.get('delta_population', 0))
        if not np.isnan(delta_pop):
            stability = 1.0 / (1.0 + abs(delta_pop))
            reward += REWARD_WEIGHTS['stability_bonus'] * stability
    # Penalty for actions (regularization)
    if actions is not None and len(actions) > 0:
        action_penalty = 0.01 * np.sum(np.square(actions))
        reward -= action_penalty
    # Basic shift for positive values
    reward += 1.0
    return float(np.clip(reward, -20.0, 20.0))
# ===== NEURAL NETWORKS =====
class Actor(nn.Module):
    """Enhanced actor architecture"""
    def __init__(self, state_dim: int, action_dim: int):
        super(Actor, self).__init__()
        self.fc1 = nn.Linear(state_dim, 400)
        self.bn1 = nn.BatchNorm1d(400)
        self.fc2 = nn.Linear(400, 300)
        self.bn2 = nn.BatchNorm1d(300)
        self.fc3 = nn.Linear(300, action_dim)
        self.dropout = nn.Dropout(0.1)
        # Weight initialization
        nn.init.xavier_uniform_(self.fc1.weight)
        nn.init.xavier_uniform_(self.fc2.weight)
        nn.init.uniform_(self.fc3.weight, -3e-3, 3e-3)
    def forward(self, state):
        if state.dim() == 1:
            state = state.unsqueeze(0)
        x = self.fc1(state)
        if x.size(0) > 1:  # BatchNorm only if batch_size > 1
            x = self.bn1(x)
        x = F.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        if x.size(0) > 1:
            x = self.bn2(x)
        x = F.relu(x)
        x = self.dropout(x)
        x = torch.tanh(self.fc3(x))
        return x
class Critic(nn.Module):
    """Enhanced critic architecture"""
    def __init__(self, state_dim: int, action_dim: int):
        super(Critic, self).__init__()
        self.state_fc = nn.Linear(state_dim, 400)
        self.state_bn = nn.BatchNorm1d(400)
        self.action_fc = nn.Linear(action_dim, 100)
        self.combined_fc1 = nn.Linear(500, 300)
        self.combined_bn = nn.BatchNorm1d(300)
        self.combined_fc2 = nn.Linear(300, 1)
        self.dropout = nn.Dropout(0.1)
        # Weight initialization
        nn.init.xavier_uniform_(self.state_fc.weight)
        nn.init.xavier_uniform_(self.action_fc.weight)
        nn.init.xavier_uniform_(self.combined_fc1.weight)
        nn.init.uniform_(self.combined_fc2.weight, -3e-3, 3e-3)
    def forward(self, state, action):
        if state.dim() == 1:
            state = state.unsqueeze(0)
        if action.dim() == 1:
            action = action.unsqueeze(0)
        # State processing
        state_feat = self.state_fc(state)
        if state_feat.size(0) > 1:
            state_feat = self.state_bn(state_feat)
        state_feat = F.relu(state_feat)
        # Action processing
        action_feat = F.relu(self.action_fc(action))
        # Combination
        combined = torch.cat([state_feat, action_feat], dim=1)
        x = self.combined_fc1(combined)
        if x.size(0) > 1:
            x = self.combined_bn(x)
        x = F.relu(x)
        x = self.dropout(x)
        q_value = self.combined_fc2(x)
        return q_value
# ===== MADDPG AGENT =====
class MADDPGAgent:
    """Enhanced MADDPG agent with detailed monitoring"""
    def __init__(self, agent_id: str, state_dim: int, action_dim: int):
        self.agent_id = agent_id
        self.state_dim = state_dim
        self.action_dim = action_dim
        # Networks
        self.actor = Actor(state_dim, action_dim).to(DEVICE)
        self.actor_target = Actor(state_dim, action_dim).to(DEVICE)
        self.critic = Critic(state_dim, action_dim).to(DEVICE)
        self.critic_target = Critic(state_dim, action_dim).to(DEVICE)
        # Initialize target networks
        self.actor_target.load_state_dict(self.actor.state_dict())
        self.critic_target.load_state_dict(self.critic.state_dict())
        # Optimizers
        self.actor_optimizer = optim.Adam(self.actor.parameters(), lr=1e-4)
        self.critic_optimizer = optim.Adam(self.critic.parameters(), lr=1e-3)
        # Hyperparameters
        self.gamma = 0.99
        self.tau = 0.001
        # Metrics for analysis
        self.actor_losses = []
        self.critic_losses = []
        self.q_values = []
        self.update_count = 0
    def act(self, state, noise_std=0.2, training=True):
        """Action generation with noise for exploration"""
        self.actor.eval()
        try:
            with torch.no_grad():
                if isinstance(state, np.ndarray):
                    state_tensor = torch.FloatTensor(state).to(DEVICE)
                else:
                    state_tensor = state.to(DEVICE)
                action = self.actor(state_tensor)
                action = action.cpu().data.numpy()
                if action.ndim > 1:
                    action = action[0]
        except Exception as e:
            print(f"Error in act: {e}")
            action = np.random.uniform(-1, 1, size=self.action_dim)
        if training and noise_std > 0:
            noise = np.random.normal(0, noise_std, size=action.shape)
            action = action + noise
        self.actor.train()
        return np.clip(action, -1.0, 1.0)
    def update(self, batch_states, batch_actions, batch_rewards,
               batch_next_states, batch_dones):
        """Update agent parameters"""
        if len(batch_states) < 4:
            return
        try:
            # Convert to tensors
            states = torch.FloatTensor(np.array(batch_states)).to(DEVICE)
            actions = torch.FloatTensor(np.array(batch_actions)).to(DEVICE)
            rewards = torch.FloatTensor(batch_rewards).to(DEVICE).unsqueeze(1)
            next_states = torch.FloatTensor(np.array(batch_next_states)).to(DEVICE)
            dones = torch.FloatTensor(batch_dones).to(DEVICE).unsqueeze(1)
            # Check dimensions
            if states.dim() == 1:
                states = states.unsqueeze(0)
            if next_states.dim() == 1:
                next_states = next_states.unsqueeze(0)
            if actions.dim() == 1:
                actions = actions.unsqueeze(0)
            # Update critic
            with torch.no_grad():
                next_actions = self.actor_target(next_states)
                target_q = self.critic_target(next_states, next_actions)
                target_q = rewards + (self.gamma * target_q * (1 - dones))
            current_q = self.critic(states, actions)
            # Save metrics
            self.q_values.append(current_q.mean().item())
            critic_loss = F.mse_loss(current_q, target_q)
            self.critic_losses.append(critic_loss.item())
            self.critic_optimizer.zero_grad()
            critic_loss.backward()
            torch.nn.utils.clip_grad_norm_(self.critic.parameters(), 1.0)
            self.critic_optimizer.step()
            # Update actor (every second step)
            if self.update_count % 2 == 0:
                predicted_actions = self.actor(states)
                actor_loss = -self.critic(states, predicted_actions).mean()
                self.actor_losses.append(actor_loss.item())
                self.actor_optimizer.zero_grad()
                actor_loss.backward()
                torch.nn.utils.clip_grad_norm_(self.actor.parameters(), 1.0)
                self.actor_optimizer.step()
                # Soft update of target networks
                self._soft_update(self.actor_target, self.actor)
                self._soft_update(self.critic_target, self.critic)
            self.update_count += 1
        except Exception as e:
            print(f"Error in update agent {self.agent_id}: {e}")
    def _soft_update(self, target_net, source_net):
        """Soft update of target networks"""
        for target_param, source_param in zip(target_net.parameters(),
                                            source_net.parameters()):
            target_param.data.copy_(
                self.tau * source_param.data + (1.0 - self.tau) * target_param.data
            )
    def get_metrics(self):
        """Get metrics for analysis"""
        return {
            'actor_loss': np.mean(self.actor_losses[-10:]) if self.actor_losses else 0.0,
            'critic_loss': np.mean(self.critic_losses[-10:]) if self.critic_losses else 0.0,
            'avg_q_value': np.mean(self.q_values[-10:]) if self.q_values else 0.0,
            'update_count': self.update_count
        }
# ===== EXPERIENCE BUFFER =====
class ReplayBuffer:
    """Enhanced experience buffer with data validity checks"""
    def __init__(self, capacity=50000):
        self.capacity = capacity
        self.buffer = []
        self.position = 0
    def push(self, state, action, reward, next_state, done):
        """Add experience with checks for NaN"""
        try:
            # Check for data validity
            if (np.isnan(state).any() or np.isnan(action).any() or
                np.isnan(reward) or np.isnan(next_state).any()):
                return False
            experience = (
                np.array(state, dtype=np.float32),
                np.array(action, dtype=np.float32),
                float(reward),
                np.array(next_state, dtype=np.float32),
                bool(done)
            )
            if len(self.buffer) < self.capacity:
                self.buffer.append(experience)
            else:
                self.buffer[self.position] = experience
            self.position = (self.position + 1) % self.capacity
            return True
        except Exception as e:
            print(f"Error in ReplayBuffer.push: {e}")
            return False
    def sample(self, batch_size):
        """Batch sampling"""
        if len(self.buffer) < batch_size:
            return None
        try:
            indices = np.random.choice(len(self.buffer), batch_size, replace=False)
            batch = [self.buffer[idx] for idx in indices]
            states, actions, rewards, next_states, dones = zip(*batch)
            return states, actions, rewards, next_states, dones
        except Exception as e:
            print(f"Error in ReplayBuffer.sample: {e}")
            return None
    def __len__(self):
        return len(self.buffer)
# ===== ENHANCED EVOLUTION =====
class EnhancedEvolution:
    """Enhanced evolutionary algorithm with adaptive parameters"""
    def __init__(self):
        self.generation = 0
        self.mutation_rate = 0.1
        self.mutation_strength = 0.02
        self.elite_fraction = 0.3
        # Adaptive parameters
        self.performance_history = []
        self.stagnation_counter = 0
        self.max_stagnation = 5
    def evolve_population(self, agents: Dict[str, MADDPGAgent],
                         fitness_scores: Dict[str, float]) -> Dict[str, float]:
        """Population evolution with improved selection and diversity"""
        if len(agents) < 2:
            return {}
        try:
            # Clean fitness from NaN
            clean_fitness = {}
            for agent_id, fitness in fitness_scores.items():
                if np.isnan(fitness) or np.isinf(fitness):
                    clean_fitness[agent_id] = -999.0
                else:
                    clean_fitness[agent_id] = float(fitness)
            # Analyze stagnation
            current_best = max(clean_fitness.values()) if clean_fitness else 0
            self.performance_history.append(current_best)
            if len(self.performance_history) > 5:
                recent_improvement = (self.performance_history[-1] -
                                    self.performance_history[-5])
                if abs(recent_improvement) < 0.01:
                    self.stagnation_counter += 1
                else:
                    self.stagnation_counter = 0
            # Adapt parameters on stagnation
            if self.stagnation_counter > self.max_stagnation:
                self.mutation_rate = min(0.3, self.mutation_rate * 1.2)
                self.mutation_strength = min(0.1, self.mutation_strength * 1.1)
                self.stagnation_counter = 0
            else:
                self.mutation_rate = max(0.05, self.mutation_rate * 0.99)
                self.mutation_strength = max(0.01, self.mutation_strength * 0.99)
            # Sort by fitness
            agent_items = list(agents.items())
            sorted_agents = sorted(agent_items,
                                 key=lambda x: clean_fitness.get(x[0], -999),
                                 reverse=True)
            elite_count = max(1, int(len(sorted_agents) * self.elite_fraction))
            improvements = {}
            mutations_applied = 0
            # Mutate non-elite agents
            for i in range(elite_count, len(sorted_agents)):
                agent_id, agent = sorted_agents[i]
                improvement = self._adaptive_mutate_agent(agent)
                improvements[agent_id] = improvement
                mutations_applied += 1
            self.generation += 1
            # Logging
            if mutations_applied > 0:
                valid_improvements = [v for v in improvements.values()
                                    if not np.isnan(v) and not np.isinf(v)]
                if valid_improvements:
                    avg_improvement = np.mean(valid_improvements)
                    print(f"🧬 Evolution G{self.generation}: {mutations_applied} mutations, "
                          f"improvement: {avg_improvement:.4f}")
            return improvements
        except Exception as e:
            print(f"Error in evolution: {e}")
            return {}
    def _adaptive_mutate_agent(self, agent: MADDPGAgent) -> float:
        """Adaptive agent mutation"""
        total_change = 0.0
        param_count = 0
        try:
            with torch.no_grad():
                for param in agent.actor.parameters():
                    if random.random() < self.mutation_rate:
                        noise = torch.randn_like(param) * self.mutation_strength
                        old_param = param.clone()
                        param.add_(noise)
                        change = torch.sum(torch.abs(param - old_param)).item()
                        total_change += change
                        param_count += param.numel()
            return total_change / max(param_count, 1) if param_count > 0 else 0.0
        except Exception as e:
            print(f"Error in mutation: {e}")
            return 0.0
# ===== SIMPLIFIED (BASE) DARWIN-GÖDEL MACHINE =====
class AdvancedDGM:
    """Simplified Darwin-Gödel Machine implementation"""
    def __init__(self):
        self.expertise_level = 0.0
        self.last_adaptation_epoch = -1
        self.cooldown = 10
        # Architecture modifications
        self.architecture_changes = 0
        self.last_architecture_change = -30
        # Crisis recovery system
        self.crisis_specialists = {}
        self.crisis_threshold = -5.0
        self.crisis_detected = False
        # Automatic reward design
        self.reward_components = REWARD_WEIGHTS.copy()
        self.reward_adaptation_history = []
        # Meta-learning
        self.meta_learning_memory = {}
        self.adaptation_success_rate = 0.0
    def adapt_system(self, epoch: int, active_regions: List[str],
                    recent_performance: Dict = None,
                    agents: Dict[str, MADDPGAgent] = None) -> Dict[str, Any]:
        """Comprehensive system adaptation inspired by the Darwin-Gödel Machine idea"""
        if epoch - self.last_adaptation_epoch < self.cooldown:
            return self._get_default_adaptations()
        adaptations = self._get_default_adaptations()
        try:
            # 1. Crisis detection
            crisis_detected = self._detect_crisis(recent_performance)
            if crisis_detected and not self.crisis_detected:
                print(f"🚨 DGM: Crisis detected at epoch {epoch}")
                self.crisis_detected = True
                adaptations.update(self._crisis_response(agents))
            elif not crisis_detected and self.crisis_detected:
                print(f"✅ DGM: Crisis overcome at epoch {epoch}")
                self.crisis_detected = False
                adaptations.update(self._post_crisis_adaptation(agents))
            # 2. Self-optimization of architecture
            if epoch - self.last_architecture_change > 29:
                arch_changes = self._self_modify_architecture(agents)
                if arch_changes > 0:
                    adaptations['architecture_modified'] = True
                    self.architecture_changes += arch_changes
                    self.last_architecture_change = epoch
                    print(f"🔧 DGM: Architecture changes: {arch_changes}")
            # 3. Automatic reward function design
            reward_changes = self._redesign_reward_function(recent_performance)
            if reward_changes:
                adaptations['reward_function_modified'] = True
                print(f"🎯 DGM: Reward function adapted")
            # 4. Environment adaptation
            env_adaptations = self._environmental_adaptation(epoch, recent_performance)
            adaptations.update(env_adaptations)
            self.expertise_level = min(self.expertise_level + 0.01, 1.0)
            adaptations['confidence'] = 0.5 + self.expertise_level * 0.4
            self.last_adaptation_epoch = epoch
        except Exception as e:
            print(f"⚠️ DGM: Adaptation error: {e}")
            return self._get_default_adaptations()
        return adaptations
    def _detect_crisis(self, recent_performance: Dict) -> bool:
        """Detecting crisis situations"""
        if not recent_performance:
            return False
        try:
            perf_values = []
            for v in recent_performance.values():
                if isinstance(v, (int, float)) and not np.isnan(v) and not np.isinf(v):
                    perf_values.append(v)
            if perf_values:
                avg_perf = np.mean(perf_values)
                return avg_perf < self.crisis_threshold
            return False
        except:
            return False
    def _crisis_response(self, agents: Dict[str, MADDPGAgent]) -> Dict[str, Any]:
        """Emergency crisis response"""
        adaptations = {}
        adaptations['learning_rate_multiplier'] = 1.5
        adaptations['exploration_bonus'] = 0.1
        adaptations['mutation_strength_multiplier'] = 2.0
        if agents:
            self._store_crisis_specialists(agents)
        return adaptations
    def _post_crisis_adaptation(self, agents: Dict[str, MADDPGAgent]) -> Dict[str, Any]:
        """Adaptation after overcoming a crisis"""
        adaptations = {}
        adaptations['learning_rate_multiplier'] = 0.8
        adaptations['exploration_bonus'] = -0.05
        if self.crisis_specialists and agents:
            self._transfer_crisis_knowledge(agents)
        return adaptations
    def _self_modify_architecture(self, agents: Dict[str, MADDPGAgent]) -> int:
        """Self-modification of agent architectures"""
        if not agents:
            return 0
        modifications = 0
        try:
            # Example modification: changing dropout rate
            for agent in list(agents.values())[:2]:
                for module in agent.actor.modules():
                    if isinstance(module, nn.Dropout):
                        old_p = module.p
                        new_p = max(0.05, min(0.3, old_p + random.uniform(-0.05, 0.05)))
                        module.p = new_p
                        modifications += 1
        except:
            pass
        return modifications
    def _redesign_reward_function(self, recent_performance: Dict) -> bool:
        """Automatic reward function design"""
        if not recent_performance or len(self.reward_adaptation_history) < 5:
            self.reward_adaptation_history.append(recent_performance)
            return False
        try:
            recent_trend = np.mean([p.get('mean_reward', 0) for p in self.reward_adaptation_history[-3:]])
            earlier_trend = np.mean([p.get('mean_reward', 0) for p in self.reward_adaptation_history[-6:-3]])
            if recent_trend < earlier_trend * 0.95:
                # Adapt reward weights
                for key in self.reward_components:
                    if 'rate' in key or 'balance' in key:
                        old_weight = REWARD_WEIGHTS[key]
                        new_weight = old_weight * (1 + random.uniform(-0.1, 0.1))
                        REWARD_WEIGHTS[key] = np.clip(new_weight, old_weight * 0.5, old_weight * 1.5)
                self.reward_adaptation_history.append(recent_performance)
                return True
            self.reward_adaptation_history.append(recent_performance)
            return False
        except:
            return False
    def _environmental_adaptation(self, epoch: int, recent_performance: Dict) -> Dict[str, Any]:
        """Adaptation to environmental changes"""
        adaptations = {}
        if recent_performance:
            try:
                perf_values = [v for v in recent_performance.values()
                              if isinstance(v, (int, float)) and not np.isnan(v)]
                if perf_values:
                    avg_perf = np.mean(perf_values)
                    if avg_perf > 2.0:
                        adaptations['learning_rate_multiplier'] = 0.95
                        adaptations['exploration_bonus'] = -0.01
                    elif avg_perf < -1.0:
                        adaptations['learning_rate_multiplier'] = 1.05
                        adaptations['exploration_bonus'] = 0.02
            except:
                pass
        return adaptations
    def _store_crisis_specialists(self, agents: Dict[str, MADDPGAgent]):
        """Storing crisis specialist agents"""
        try:
            if len(agents) > 0:
                best_agents = sorted(agents.items(),
                                   key=lambda x: np.mean(x[1].q_values[-10:]) if x[1].q_values else -999,
                                   reverse=True)[:3]
                crisis_type = f"crisis_{len(self.crisis_specialists)}"
                self.crisis_specialists[crisis_type] = {
                    'agents_params': [agent.actor.state_dict() for _, agent in best_agents],
                    'timestamp': time.time()
                }
        except:
            pass
    def _transfer_crisis_knowledge(self, agents: Dict[str, MADDPGAgent]):
        """Transferring knowledge from crisis agents"""
        try:
            if not self.crisis_specialists or not agents:
                return
            latest_crisis = max(self.crisis_specialists.items(), key=lambda x: x[1]['timestamp'])
            crisis_params = latest_crisis[1]['agents_params']
            if crisis_params and len(agents) > 0:
                agents_list = list(agents.values())
                for i, crisis_param in enumerate(crisis_params[:len(agents_list)]):
                    agent = agents_list[i]
                    with torch.no_grad():
                        for (name, agent_param), (_, crisis_param_tensor) in zip(
                            agent.actor.named_parameters(), crisis_param.items()):
                            if agent_param.shape == crisis_param_tensor.shape:
                                agent_param.data = 0.9 * agent_param.data + 0.1 * crisis_param_tensor
        except:
            pass
    def _get_default_adaptations(self):
        """Default adaptations"""
        return {
            'learning_rate_multiplier': 1.0,
            'exploration_bonus': 0.0,
            'confidence': 0.5,
            'architecture_modified': False,
            'reward_function_modified': False
        }
print("✅ MADDPG CORE V1.1 - All basic components loaded")
print("🔧 FIXED: imports, tqdm fallback, error handling")
print("📦 Available: Actor, Critic, MADDPGAgent, ReplayBuffer, EnhancedEvolution, AdvancedDGM")
print("🎯 reward function: calculate_honest_reward")
print("⚙️ Configuration: CONFIG")
# -*- coding: utf-8 -*-
"""
MADDPG TRAINER - Fixed Version 1.1
File 2/3: Environment, Trainer, Fixed Import
FIXED: tqdm import, error handling, stability
"""
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from collections import defaultdict
from typing import Dict, List, Tuple, Optional, Union, Any
# Fixed tqdm import
try:
    from tqdm.auto import tqdm
except ImportError:
    try:
        from tqdm import tqdm
    except ImportError:
        def tqdm(iterable, *args, **kwargs):
            desc = kwargs.get('desc', '')
            total = len(iterable) if hasattr(iterable, '__len__') else None
            for i, item in enumerate(iterable):
                if desc and total:
                    if i % max(1, total // 20) == 0:
                        print(f"{desc}: {i+1}/{total}")
                yield item
# Import variables directly (to avoid module import issues)
import sys
import os
# Check if needed classes are in globals()
if 'MADDPGAgent' not in globals():
    print("⚠️ Classes not found in globals(), need to run the first file")
print("🚀 MADDPG TRAINER V1.1 - FIXED VERSION")
print("📊 tqdm import and error handling")
# ===== COPY CONSTANTS (in case of import issues) =====
if 'CONFIG' not in globals():
    CONFIG = {
        'training_epochs': 1000,
        'testing_epochs': 200,
        'region_addition_phase': 600,
        'total_regions': 86,
        'batch_size': 32,
        'episode_length': 15,
        'buffer_size': 50000,
        'log_interval': 10,
        'milestone_interval': 10,
    }
if 'DEVICE' not in globals():
    import torch
    DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if 'calculate_honest_reward' not in globals():
    REWARD_WEIGHTS = {
        'population': 2.0,
        'natural_increase_rate': 3.0,
        'birth_rate': 2.5,
        'death_rate': -2.0,
        'migration_balance': 2.2,
        'gdp_per_capita': 1.8,
        'average_wage': 1.5,
        'unemployment_rate': -1.8,
        'stability_bonus': 1.0
    }
    def calculate_honest_reward(region_data: dict, actions: np.ndarray = None) -> float:
        """Honest reward function"""
        if not region_data:
            return 0.0
        reward = 0.0
        base_components = ['population', 'natural_increase_rate', 'birth_rate',
                          'death_rate', 'migration_balance', 'gdp_per_capita',
                          'average_wage', 'unemployment_rate']
        for component in base_components:
            if component in region_data:
                value = float(region_data[component])
                if not np.isnan(value) and not np.isinf(value):
                    weight = REWARD_WEIGHTS.get(component, 0)
                    reward += weight * np.clip(value, -3.0, 3.0)
        delta_weights = {
            'delta_population': 1.5,
            'delta_birth_rate': 2.0,
            'delta_gdp_per_capita': 1.8,
            'delta_migration_balance': 1.6,
            'delta_average_wage': 1.2
        }
        for delta_key, weight in delta_weights.items():
            if delta_key in region_data:
                delta_value = float(region_data[delta_key])
                if not np.isnan(delta_value) and not np.isinf(delta_value):
                    reward += weight * np.clip(delta_value, -1.0, 1.0)
        if 'delta_population' in region_data:
            delta_pop = float(region_data.get('delta_population', 0))
            if not np.isnan(delta_pop):
                stability = 1.0 / (1.0 + abs(delta_pop))
                reward += REWARD_WEIGHTS['stability_bonus'] * stability
        if actions is not None and len(actions) > 0:
            action_penalty = 0.01 * np.sum(np.square(actions))
            reward -= action_penalty
        reward += 1.0
        return float(np.clip(reward, -20.0, 20.0))
# ===== MONITORING  =====
class SmartMonitor:
    """Smart monitor"""
    def __init__(self):
        self.data = defaultdict(lambda: defaultdict(list))
        self.agent_creation_logged = False
        self.last_milestone = 0
    def start(self):
        timestamp = datetime.now().strftime('%Y-%m-%d_%H-%M-%S')
        print(f"⏰ Experiment started: {timestamp}")
    def log_agent_creation(self, agent_count: int):
        """Log agent creation"""
        milestones = [5, 10, 20, 30, 40, 50, 60, 70, 80, 86]
        for milestone in milestones:
            if agent_count >= milestone and self.last_milestone < milestone:
                print(f"✅ Created {agent_count} agents for regions")
                self.last_milestone = milestone
                break
    def log(self, algorithm: str, epoch: int, reward: float, regions_count: int, info: dict = None):
        """Log training progress"""
        self.data[algorithm]['epochs'].append(epoch)
        self.data[algorithm]['rewards'].append(reward if not np.isnan(reward) else 0.0)
        self.data[algorithm]['regions'].append(regions_count)
        if info:
            for key, value in info.items():
                self.data[algorithm][key].append(value)
    def summary(self):
        """Final report"""
        print("\
" + "🏆" * 50)
        print("TRAINING RESULTS")
        print("🏆" * 50)
        for algo, metrics in self.data.items():
            if metrics['rewards']:
                clean_rewards = [r for r in metrics['rewards'] if not np.isnan(r)]
                if clean_rewards:
                    final = np.mean(clean_rewards[-20:]) if len(clean_rewards) >= 20 else np.mean(clean_rewards)
                    print(f"\
{algo}: Final={final:.3f}, "
                          f"Max={max(clean_rewards):.3f}, "
                          f"Average={np.mean(clean_rewards):.3f}, "
                          f"Epochs={len(clean_rewards)}")
# ===== ENHANCED ENVIRONMENT =====
class DemographyEnv:
    """Demographic environment"""
    def __init__(self, df: pd.DataFrame, obs_cols: List[str]):
        self.df = df
        self.obs_cols = obs_cols
        self.years = sorted(df['year'].unique())
        self.regions = sorted(df['region_name'].unique())
        self.current_epoch = 0
        self.episode_length = CONFIG['episode_length']
        self.state_dim = len(obs_cols)
        self.action_dim = 4
        self.active_regions = []
        self.current_year_idx = 0
        self.episode_step = 0
        self.episode_rewards = []
        print(f"🌍 Environment: {len(self.regions)} regions, {len(self.years)} years")
        print(f"📊 State: {self.state_dim}D, Actions: {self.action_dim}D")
    def get_active_regions_for_epoch(self, epoch: int) -> List[str]:
        """Gradual addition of regions"""
        if epoch < CONFIG['region_addition_phase']:
            progress = epoch / CONFIG['region_addition_phase']
            min_regions = 5
            target_count = int(min_regions + progress * (len(self.regions) - min_regions))
            target_count = min(target_count, len(self.regions))
            return self.regions[:target_count]
        else:
            return self.regions.copy()
    def reset(self, epoch: int = 0):
        """Reset environment for a new epoch"""
        self.current_epoch = epoch
        self.active_regions = self.get_active_regions_for_epoch(epoch)
        max_start_year = len(self.years) - self.episode_length - 1
        self.current_year_idx = np.random.randint(0, max(0, max_start_year) + 1)
        self.episode_step = 0
        self.episode_rewards = []
        observations = {}
        for region in self.active_regions:
            obs = self._get_region_observation(region, self.years[self.current_year_idx])
            observations[region] = obs
        info = {
            'epoch': epoch,
            'year': self.years[self.current_year_idx],
            'active_regions': len(self.active_regions),
            'phase': 'expansion' if epoch < CONFIG['region_addition_phase'] else 'stabilization'
        }
        return observations, info
    def step(self, actions: Dict[str, np.ndarray]):
        """Environment step with honest rewards"""
        rewards = {}
        next_observations = {}
        total_reward = 0.0
        current_year = self.years[self.current_year_idx]
        for region in self.active_regions:
            current_obs = self._get_region_observation(region, current_year)
            action = actions.get(region, np.zeros(self.action_dim))
            action = np.clip(action, -1.0, 1.0)
            next_obs = self._apply_action_to_observation(current_obs, action)
            next_obs = self._add_environment_noise(next_obs)
            next_observations[region] = next_obs
            region_data = self._observation_to_region_data(current_obs, next_obs)
            reward = calculate_honest_reward(region_data, action)
            rewards[region] = reward
            total_reward += reward
            self.episode_rewards.append(reward)
        self.current_year_idx += 1
        self.episode_step += 1
        done = (self.episode_step >= self.episode_length or
                self.current_year_idx >= len(self.years) - 1)
        mean_reward = total_reward / len(self.active_regions) if self.active_regions else 0.0
        info = {
            'epoch': self.current_epoch,
            'year': current_year,
            'step': self.episode_step,
            'total_reward': total_reward,
            'mean_reward': mean_reward,
            'episode_length': len(self.episode_rewards),
            'active_regions_count': len(self.active_regions),
            'phase': 'expansion' if self.current_epoch < CONFIG['region_addition_phase'] else 'stabilization',
            'regions_rewards': rewards,
            'done': done
        }
        return next_observations, rewards, total_reward, done, info
    def _get_region_observation(self, region: str, year: int) -> np.ndarray:
        """Get observation for a region"""
        region_data = self.df[(self.df['region_name'] == region) & (self.df['year'] == year)]
        if len(region_data) == 0:
            region_subset = self.df[self.df['region_name'] == region]
            if len(region_subset) > 0:
                year_diffs = np.abs(region_subset['year'].values - year)
                closest_idx = np.argmin(year_diffs)
                region_data = region_subset.iloc[[closest_idx]]
            else:
                return np.zeros(len(self.obs_cols), dtype=np.float32)
        if len(region_data) > 0:
            row = region_data.iloc[0]
            observation = row[self.obs_cols].values.astype(np.float32)
            observation = np.nan_to_num(observation, nan=0.0, posinf=3.0, neginf=-3.0)
            observation = np.clip(observation, -3.0, 3.0)
            return observation
        else:
            return np.zeros(len(self.obs_cols), dtype=np.float32)
    def _apply_action_to_observation(self, observation: np.ndarray, action: np.ndarray) -> np.ndarray:
        """Apply actions to observations"""
        modified_obs = observation.copy()
        if len(modified_obs) >= 8 and len(action) >= 4:
            modified_obs[1] += action[0] * 0.3  # birth_rate
            modified_obs[2] -= action[1] * 0.2  # death_rate (inverse)
            if len(modified_obs) > 4:
                modified_obs[4] += action[2] * 0.4  # migration_balance
            if len(modified_obs) > 5:
                modified_obs[5] += action[3] * 0.25  # gdp_per_capita
            if len(modified_obs) > 3:
                modified_obs[3] = modified_obs[1] - modified_obs[2]
            if len(modified_obs) >= 16:
                delta_start = 8
                if len(modified_obs) > delta_start:
                    modified_obs[delta_start] = (modified_obs[0] - observation[0])
                if len(modified_obs) > delta_start + 1:
                    modified_obs[delta_start + 1] = (modified_obs[1] - observation[1])
        modified_obs = np.clip(modified_obs, -3.0, 3.0)
        return modified_obs
    def _add_environment_noise(self, observation: np.ndarray) -> np.ndarray:
        """Add realistic environment noise"""
        noise = np.random.normal(0, 0.02, size=observation.shape)
        systematic_noise = 0.01 * np.sin(self.current_year_idx * 0.1) * np.ones_like(observation)
        noisy_obs = observation + noise + systematic_noise
        return np.clip(noisy_obs, -3.0, 3.0)
    def _observation_to_region_data(self, current_obs: np.ndarray, next_obs: np.ndarray) -> dict:
        """Convert observations to region data for reward calculation"""
        region_data = {}
        if len(next_obs) >= 8:
            keys = ['population', 'birth_rate', 'death_rate', 'natural_increase_rate',
                   'migration_balance', 'gdp_per_capita', 'unemployment_rate', 'average_wage']
            for i, key in enumerate(keys):
                if i < len(next_obs):
                    region_data[key] = float(next_obs[i])
        if len(current_obs) >= 8 and len(next_obs) >= 8:
            delta_keys = ['delta_population', 'delta_birth_rate', 'delta_death_rate',
                         'delta_natural_increase_rate', 'delta_migration_balance',
                         'delta_gdp_per_capita', 'delta_unemployment_rate', 'delta_average_wage']
            for i, key in enumerate(delta_keys):
                if i < min(len(current_obs), len(next_obs)):
                    region_data[key] = float(next_obs[i] - current_obs[i])
        return region_data
    def get_state_action_dims(self):
        return self.state_dim, self.action_dim
# ===== ENHANCED TRAINER =====
class EnhancedTrainer:
    """Enhanced trainer with visualization and analysis"""
    def __init__(self, env: DemographyEnv):
        self.env = env
        self.agents = {}
        self.replay_buffers = {}
        # Check for class availability
        if 'EnhancedEvolution' in globals():
            self.evolution = EnhancedEvolution()
        else:
            self.evolution = None
            print("⚠️ EnhancedEvolution not found")
        if 'AdvancedDGM' in globals():
            self.dgm = AdvancedDGM()
        else:
            self.dgm = None
            print("⚠️ AdvancedDGM not found")
        self.monitor = SmartMonitor()
        state_dim, action_dim = env.get_state_action_dims()
        print(f"🎯 Trainer created: state {state_dim}D, actions {action_dim}D")
    def setup_agents(self, active_regions: List[str]):
        """Set up agents without spam in logs"""
        if 'MADDPGAgent' not in globals():
            print("❌ MADDPGAgent not found in globals()")
            return
        if 'ReplayBuffer' not in globals():
            print("❌ ReplayBuffer not found in globals()")
            return
        state_dim, action_dim = self.env.get_state_action_dims()
        for region in active_regions:
            if region not in self.agents:
                self.agents[region] = MADDPGAgent(region, state_dim, action_dim)
                self.replay_buffers[region] = ReplayBuffer(CONFIG['buffer_size'])
        self.monitor.log_agent_creation(len(self.agents))
    def collect_experience(self, observations, actions, rewards, next_observations, dones):
        """Collect experience"""
        for region in self.env.active_regions:
            if (region in observations and region in next_observations and
                region in actions and region in rewards):
                obs = observations[region]
                next_obs = next_observations[region]
                action = actions[region]
                reward = rewards[region]
                done = dones
                if (not np.isnan(obs).any() and not np.isnan(next_obs).any() and
                    not np.isnan(action).any() and not np.isnan(reward)):
                    if region in self.replay_buffers:
                        self.replay_buffers[region].push(obs, action, reward, next_obs, done)
    def update_agents(self):
        """Update agents"""
        updates_performed = 0
        for region in self.env.active_regions:
            if region in self.agents and region in self.replay_buffers:
                buffer = self.replay_buffers[region]
                if len(buffer) >= CONFIG['batch_size']:
                    batch = buffer.sample(CONFIG['batch_size'])
                    if batch is not None:
                        states, actions, rewards, next_states, dones = batch
                        if (len(states) == CONFIG['batch_size'] and
                            all(not np.isnan(r) for r in rewards)):
                            self.agents[region].update(states, actions, rewards, next_states, dones)
                            updates_performed += 1
        return updates_performed
    def get_actions(self, observations, noise_std=0.2):
        """Get actions from agents"""
        actions = {}
        for region in self.env.active_regions:
            if region in self.agents and region in observations:
                action = self.agents[region].act(observations[region], noise_std, training=True)
                actions[region] = action
            else:
                actions[region] = np.random.uniform(-1, 1, size=self.env.action_dim)
        return actions
    def train_algorithm(self, algorithm: str, epochs: int, testing_epochs: int = 0) -> Tuple[List[float], List[float]]:
        """Train algorithm with testing"""
        print(f"\
🚀 TRAINING {algorithm}")
        print(f"📊 Training: {epochs} epochs | Testing: {testing_epochs} epochs")
        print("=" * 60)
        # Reset components
        self.agents = {}
        self.replay_buffers = {}
        if 'EVO' in algorithm and self.evolution:
            if 'EnhancedEvolution' in globals():
                self.evolution = EnhancedEvolution()
        if 'DGM' in algorithm and self.dgm:
            if 'AdvancedDGM' in globals():
                self.dgm = AdvancedDGM()
        training_rewards = []
        testing_rewards = []
        noise_std = 0.3
        noise_decay = 0.998
        update_frequency = 4
        # TRAINING PHASE
        print("🎓 TRAINING PHASE")
        # Use our fallback tqdm
        for epoch in tqdm(range(epochs), desc=f"{algorithm} Training"):
            try:
                # DGM adaptations
                dgm_adaptations = {}
                if algorithm == "MADDPG-EVO-DGM" and self.dgm:
                    recent_rewards = training_rewards[-10:] if len(training_rewards) >= 10 else training_rewards
                    recent_performance = {}
                    if recent_rewards:
                        recent_performance = {
                            'mean_reward': float(np.mean(recent_rewards)),
                            'reward_trend': float(recent_rewards[-1] - recent_rewards[0]) if len(recent_rewards) > 1 else 0.0
                        }
                    dgm_adaptations = self.dgm.adapt_system(
                        epoch,
                        self.env.get_active_regions_for_epoch(epoch),
                        recent_performance,
                        self.agents
                    )
                # Training episode
                observations, info = self.env.reset(epoch)
                self.setup_agents(self.env.active_regions)
                episode_reward = 0.0
                episode_steps = 0
                done = False
                while not done and episode_steps < CONFIG['episode_length']:
                    actions = self.get_actions(observations, noise_std)
                    next_observations, rewards, total_reward, done, step_info = self.env.step(actions)
                    self.collect_experience(observations, actions, rewards, next_observations, done)
                    episode_reward += total_reward
                    episode_steps += 1
                    if episode_steps % update_frequency == 0:
                        updates = self.update_agents()
                    observations = next_observations
                # Apply DGM adaptations
                if algorithm == "MADDPG-EVO-DGM" and dgm_adaptations:
                    self._apply_dgm_adaptations(dgm_adaptations)
                # Evolution
                if "EVO" in algorithm and epoch % 15 == 0 and len(self.agents) > 1 and self.evolution:
                    fitness_scores = {}
                    for region, agent in self.agents.items():
                        if hasattr(agent, 'q_values') and agent.q_values:
                            fitness_scores[region] = np.mean(agent.q_values[-5:])
                        else:
                            fitness_scores[region] = step_info.get('regions_rewards', {}).get(region, 0.0)
                    if fitness_scores and len(fitness_scores) > 1:
                        self.evolution.evolve_population(self.agents, fitness_scores)
                # Logging
                mean_episode_reward = episode_reward / max(episode_steps, 1)
                if np.isnan(mean_episode_reward) or np.isinf(mean_episode_reward):
                    mean_episode_reward = 0.0
                training_rewards.append(mean_episode_reward)
                self.monitor.log(algorithm, epoch, mean_episode_reward, len(self.env.active_regions), step_info)
                noise_std = max(0.05, noise_std * noise_decay)
                # Training progress
                if (epoch + 1) % CONFIG['log_interval'] == 0:
                    recent_rewards = training_rewards[-CONFIG['log_interval']:]
                    avg_recent = np.mean(recent_rewards) if recent_rewards else 0
                    print(f"[{algorithm}] Epoch {epoch+1}/{epochs}: "
                          f"reward={avg_recent:.3f}, regions={len(self.env.active_regions)}, "
                          f"noise={noise_std:.3f}")
                    if self.agents:
                        sample_agent = next(iter(self.agents.values()))
                        metrics = sample_agent.get_metrics()
                        print(f"  📊 Metrics: actor_loss={metrics['actor_loss']:.4f}, "
                              f"critic_loss={metrics['critic_loss']:.4f}, "
                              f"avg_q={metrics['avg_q_value']:.3f}")
            except Exception as e:
                print(f"❌ Error in epoch {epoch}: {e}")
                training_rewards.append(0.0)
                continue
        # TESTING PHASE
        if testing_epochs > 0 and self.agents:
            print(f"\
🧪 TESTING PHASE ({testing_epochs} epochs)")
            # Freeze weights for testing
            for agent in self.agents.values():
                agent.actor.eval()
                agent.critic.eval()
            for test_epoch in tqdm(range(testing_epochs), desc=f"{algorithm} Testing"):
                try:
                    observations, info = self.env.reset(epochs + test_epoch)
                    episode_reward = 0.0
                    episode_steps = 0
                    done = False
                    while not done and episode_steps < CONFIG['episode_length']:
                        actions = self.get_actions(observations, noise_std=0.0)
                        next_observations, rewards, total_reward, done, step_info = self.env.step(actions)
                        episode_reward += total_reward
                        episode_steps += 1
                        observations = next_observations
                    mean_episode_reward = episode_reward / max(episode_steps, 1)
                    if np.isnan(mean_episode_reward) or np.isinf(mean_episode_reward):
                        mean_episode_reward = 0.0
                    testing_rewards.append(mean_episode_reward)
                except Exception as e:
                    print(f"❌ Error in test epoch {test_epoch}: {e}")
                    testing_rewards.append(0.0)
                    continue
            # Return to training mode
            for agent in self.agents.values():
                agent.actor.train()
                agent.critic.train()
        # Final report
        self._print_algorithm_summary(algorithm, training_rewards, testing_rewards)
        return training_rewards, testing_rewards
    def _apply_dgm_adaptations(self, adaptations: Dict[str, Any]):
        """Apply DGM adaptations"""
        try:
            lr_multiplier = adaptations.get('learning_rate_multiplier', 1.0)
            if not np.isnan(lr_multiplier) and not np.isinf(lr_multiplier):
                for agent in self.agents.values():
                    for param_group in agent.actor_optimizer.param_groups:
                        param_group['lr'] *= lr_multiplier
                    for param_group in agent.critic_optimizer.param_groups:
                        param_group['lr'] *= lr_multiplier
        except Exception as e:
            print(f"Error in _apply_dgm_adaptations: {e}")
    def _print_algorithm_summary(self, algorithm: str, training_rewards: List[float], testing_rewards: List[float]):
        """Print algorithm summary"""
        if training_rewards:
            clean_train_rewards = [r for r in training_rewards if not np.isnan(r) and not np.isinf(r)]
            if clean_train_rewards:
                final_train_reward = np.mean(clean_train_rewards[-20:]) if len(clean_train_rewards) >= 20 else np.mean(clean_train_rewards)
                max_train_reward = max(clean_train_rewards)
                train_improvement = clean_train_rewards[-1] - clean_train_rewards[0] if len(clean_train_rewards) > 1 else 0
                print(f"\
✅ {algorithm} - TRAINING COMPLETED:")
                print(f"  📊 Final reward: {final_train_reward:.4f}")
                print(f"  📈 Maximum reward: {max_train_reward:.4f}")
                print(f"  📊 Overall improvement: {train_improvement:.4f}")
                if testing_rewards:
                    clean_test_rewards = [r for r in testing_rewards if not np.isnan(r) and not np.isinf(r)]
                    if clean_test_rewards:
                        final_test_reward = np.mean(clean_test_rewards)
                        max_test_reward = max(clean_test_rewards)
                        print(f"  🧪 Test reward: {final_test_reward:.4f}")
                        print(f"  🧪 Max in test: {max_test_reward:.4f}")
                        print(f"  📊 Stability: {final_test_reward/final_train_reward:.3f}")
                print(f"  🤖 Trained agents: {len(self.agents)}")
                total_experience = sum(len(buf) for buf in self.replay_buffers.values())
                print(f"  💾 Total experience: {total_experience}")
            else:
                print(f"\
❌ {algorithm} failed to learn (no valid rewards)")
        else:
            print(f"\
❌ {algorithm} failed to learn (no data)")
print("✅ MADDPG TRAINER V1.1 - All components loaded")
print("🔧 FIXED: tqdm import, fallback functions, error handling")
print("📦 Available: SmartMonitor, DemographyEnv, EnhancedTrainer")
print("🎯 Ready to run experiments")
# -*- coding: utf-8 -*-
"""
MADDPG EXPERIMENT RUNNER - Fixed Version 1.1
File 3/3: Experiments, Visualization, Analysis of Results
FIXED: all imports, visualization, error handling
"""
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from typing import Dict, List, Tuple, Optional
# Fixed tqdm import
try:
    from tqdm.auto import tqdm
except ImportError:
    try:
        from tqdm import tqdm
    except ImportError:
        def tqdm(iterable, *args, **kwargs):
            desc = kwargs.get('desc', '')
            total = len(iterable) if hasattr(iterable, '__len__') else None
            for i, item in enumerate(iterable):
                if desc and total:
                    if i % max(1, total // 20) == 0:
                        print(f"{desc}: {i+1}/{total}")
                yield item
print("🚀 MADDPG EXPERIMENT RUNNER V1.1 - FIXED VERSION")
print("📊 All imports and components fixed")
# ===== CHECK DEPENDENCIES =====
required_classes = ['CONFIG', 'calculate_honest_reward', 'DemographyEnv', 'EnhancedTrainer', 'SmartMonitor']
missing_classes = []
for cls_name in required_classes:
    if cls_name not in globals():
        missing_classes.append(cls_name)
if missing_classes:
    print(f"⚠️ Missing classes: {missing_classes}")
    print("📋 Need to run files 1 and 2 first")
# ===== FALLBACK CONSTANTS =====
if 'CONFIG' not in globals():
    CONFIG = {
        'training_epochs': 1000,
        'testing_epochs': 200,
        'region_addition_phase': 600,
        'total_regions': 86,
        'batch_size': 32,
        'episode_length': 15,
        'buffer_size': 50000,
        'log_interval': 10,
        'milestone_interval': 10,
    }
# ===== DATA PREPARATION =====
def prepare_demo_data():
    """Prepare demo data for the experiment"""
    print("📊 Preparing demo data...")
    regions = [
        "Altai Krai", "Altai Republic", "Amur Oblast", "Arkhangelsk Oblast",
        "Astrakhan Oblast", "Belgorod Oblast", "Bryansk Oblast", "Chelyabinsk Oblast",
        "Irkutsk Oblast", "Kaluga Oblast", "Moscow", "Saint Petersburg",
        "Novosibirsk Oblast", "Sverdlovsk Oblast", "Krasnoyarsk Krai", "Tatarstan"
    ]
    years = list(range(2000, 2024))
    base_cols = ['population', 'birth_rate', 'death_rate', 'natural_increase_rate',
                'migration_balance', 'gdp_per_capita', 'unemployment_rate', 'average_wage']
    data = []
    np.random.seed(42)  # For reproducibility
    for region in regions:
        base_offset = np.random.uniform(-0.5, 0.5)  # Unique offset for region
        for year in years:
            year_trend = (year - 2000) * 0.01  # Time trend
            base_pop = np.random.uniform(0.5, 3.0) + base_offset + year_trend
            birth_rate = np.random.uniform(-1.5, 1.5) + 0.1 * np.sin(year * 0.1)
            death_rate = np.random.uniform(-1.5, 1.5) + 0.05 * np.cos(year * 0.15)
            row = {
                'region_name': region,
                'year': year,
                'population': base_pop,
                'birth_rate': birth_rate,
                'death_rate': death_rate,
                'natural_increase_rate': birth_rate - death_rate,
                'migration_balance': np.random.uniform(-1.0, 1.0) + base_offset * 0.5,
                'gdp_per_capita': np.random.uniform(-1.0, 2.0) + year_trend,
                'unemployment_rate': np.random.uniform(-1.5, 1.5) - year_trend * 0.5,
                'average_wage': np.random.uniform(-1.0, 2.0) + year_trend * 0.8
            }
            data.append(row)
    df = pd.DataFrame(data)
    # Add deltas
    for col in base_cols:
        delta_col = f"delta_{col}"
        df[delta_col] = df.groupby('region_name')[col].diff().fillna(0.0)
        df[delta_col] = np.clip(df[delta_col], -1.0, 1.0)
    obs_cols = base_cols + [f"delta_{c}" for c in base_cols]
    print(f"✅ Prepared: {len(df)} records, {len(regions)} regions, {len(years)} years")
    return df, obs_cols
# ===== VISUALIZATION =====
class ExperimentVisualizer:
    """System for visualizing experiment results"""
    def __init__(self):
        # Try to set style
        try:
            if 'seaborn-v0_8' in plt.style.available:
                plt.style.use('seaborn-v0_8')
            elif 'seaborn' in plt.style.available:
                plt.style.use('seaborn')
            else:
                plt.style.use('default')
        except:
            plt.style.use('default')
        self.colors = ['#2E8B57', '#4169E1', '#DC143C', '#FF8C00', '#9932CC']
    def plot_training_curves(self, results: Dict[str, Tuple[List[float], List[float]]],
                           save_path: str = None):
        """Plot training curves"""
        try:
            fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
            # Training plot
            ax1.set_title('🎓 Training Curves of Algorithms', fontsize=14, fontweight='bold')
            algorithms_with_data = []
            for i, (algorithm, (train_rewards, test_rewards)) in enumerate(results.items()):
                if train_rewards and len(train_rewards) > 0:
                    # Filter valid rewards
                    clean_rewards = [r for r in train_rewards if not np.isnan(r) and not np.isinf(r)]
                    if clean_rewards:
                        algorithms_with_data.append(algorithm)
                        smooth_rewards = self._smooth_curve(clean_rewards, window=10)
                        epochs = range(len(smooth_rewards))
                        color = self.colors[i % len(self.colors)]
                        ax1.plot(epochs, smooth_rewards, label=algorithm,
                                color=color, linewidth=2)
                        # Confidence interval
                        if len(clean_rewards) > 20:
                            std_rewards = self._rolling_std(clean_rewards, window=10)
                            ax1.fill_between(epochs,
                                           np.array(smooth_rewards) - np.array(std_rewards),
                                           np.array(smooth_rewards) + np.array(std_rewards),
                                           alpha=0.2, color=color)
            ax1.set_xlabel('Training Epoch')
            ax1.set_ylabel('Average Reward')
            if algorithms_with_data:
                ax1.legend()
            ax1.grid(True, alpha=0.3)
            # Testing plot
            ax2.set_title('🧪 Testing Results', fontsize=14, fontweight='bold')
            test_means = []
            test_stds = []
            test_algorithms = []
            for algorithm, (train_rewards, test_rewards) in results.items():
                if test_rewards and len(test_rewards) > 0:
                    clean_test = [r for r in test_rewards if not np.isnan(r) and not np.isinf(r)]
                    if clean_test:
                        test_algorithms.append(algorithm)
                        test_means.append(np.mean(clean_test))
                        test_stds.append(np.std(clean_test))
            if test_algorithms and test_means:
                bars = ax2.bar(range(len(test_algorithms)), test_means,
                              yerr=test_stds, capsize=5,
                              color=self.colors[:len(test_algorithms)], alpha=0.7)
                ax2.set_xticks(range(len(test_algorithms)))
                ax2.set_xticklabels(test_algorithms, rotation=45, ha='right')
                ax2.set_ylabel('Average Test Reward')
                # Add values to bars
                for i, (bar, mean, std) in enumerate(zip(bars, test_means, test_stds)):
                    height = bar.get_height()
                    ax2.text(bar.get_x() + bar.get_width()/2, height + std + 0.1,
                            f'{mean:.3f}±{std:.3f}', ha='center', va='bottom', fontweight='bold')
            else:
                ax2.text(0.5, 0.5, 'No test data', ha='center', va='center',
                        transform=ax2.transAxes, fontsize=12)
            ax2.grid(True, alpha=0.3)
            plt.tight_layout()
            if save_path:
                plt.savefig(save_path, dpi=300, bbox_inches='tight')
            plt.show()
        except Exception as e:
            print(f"❌ Error in plot_training_curves: {e}")
            # Simple alternative
            print("📊 Training results:")
            for algo, (train, test) in results.items():
                if train:
                    clean_train = [r for r in train if not np.isnan(r) and not np.isinf(r)]
                    if clean_train:
                        print(f"  {algo}: average={np.mean(clean_train):.3f}, final={np.mean(clean_train[-20:]):.3f}")
    def plot_algorithm_comparison(self, final_scores: Dict[str, float]):
        """Algorithm comparison chart"""
        try:
            if not final_scores:
                print("❌ No data for algorithm comparison")
                return
            fig, ax = plt.subplots(figsize=(10, 6))
            # Filter valid scores
            clean_scores = {k: v for k, v in final_scores.items()
                           if not np.isnan(v) and not np.isinf(v)}
            if not clean_scores:
                print("❌ No valid scores for visualization")
                return
            algorithms = list(clean_scores.keys())
            scores = list(clean_scores.values())
            # Sort in descending order
            sorted_pairs = sorted(zip(algorithms, scores), key=lambda x: x[1], reverse=True)
            algorithms, scores = zip(*sorted_pairs)
            bars = ax.bar(range(len(algorithms)), scores,
                         color=self.colors[:len(algorithms)], alpha=0.8)
            # Formatting
            ax.set_title('🏆 Final Algorithm Comparison', fontsize=16, fontweight='bold')
            ax.set_xticks(range(len(algorithms)))
            ax.set_xticklabels(algorithms, rotation=45, ha='right')
            ax.set_ylabel('Final Reward')
            # Add values and medals
            medals = ['🥇', '🥈', '🥉']
            for i, (bar, score) in enumerate(zip(bars, scores)):
                medal = medals[i] if i < len(medals) else f'{i+1}.'
                height = bar.get_height()
                ax.text(bar.get_x() + bar.get_width()/2, height + 0.1,
                       f'{medal}\
{score:.3f}', ha='center', va='bottom',
                       fontweight='bold', fontsize=12)
            # Lines for comparison
            if len(scores) > 1:
                max_score = max(scores)
                for i, score in enumerate(scores[1:], 1):
                    if score != 0:
                        improvement = ((max_score - score) / abs(score) * 100)
                        ax.text(i, score/2, f'-{improvement:.1f}%', ha='center', va='center',
                               bbox=dict(boxstyle='round,pad=0.3', facecolor='red', alpha=0.3))
            ax.grid(True, alpha=0.3, axis='y')
            plt.tight_layout()
            plt.show()
        except Exception as e:
            print(f"❌ Error in plot_algorithm_comparison: {e}")
            # Simple alternative
            print("🏆 Algorithm comparison:")
            sorted_scores = sorted(final_scores.items(), key=lambda x: x[1], reverse=True)
            medals = ['🥇', '🥈', '🥉']
            for i, (algo, score) in enumerate(sorted_scores):
                medal = medals[i] if i < len(medals) else f'{i+1}.'
                print(f"  {medal} {algo}: {score:.4f}")
    def create_results_table(self, results: Dict[str, Tuple[List[float], List[float]]]) -> pd.DataFrame:
        """Create results table"""
        table_data = []
        for algorithm, (train_rewards, test_rewards) in results.items():
            if train_rewards:
                clean_train = [r for r in train_rewards if not np.isnan(r) and not np.isinf(r)]
                if clean_train:
                    row = {
                        'Algorithm': algorithm,
                        'Final Reward': np.mean(clean_train[-20:]) if len(clean_train) >= 20 else np.mean(clean_train),
                        'Maximum Reward': max(clean_train),
                        'Standard Deviation': np.std(clean_train),
                        'Improvement': clean_train[-1] - clean_train[0] if len(clean_train) > 1 else 0,
                        'Stability': np.std(clean_train[-50:]) if len(clean_train) >= 50 else np.std(clean_train),
                        'Training Epochs': len(clean_train)
                    }
                    if test_rewards:
                        clean_test = [r for r in test_rewards if not np.isnan(r) and not np.isinf(r)]
                        if clean_test:
                            row['Test Reward'] = np.mean(clean_test)
                            row['Generalization'] = np.mean(clean_test) / row['Final Reward'] if row['Final Reward'] != 0 else 0
                            row['Testing Epochs'] = len(clean_test)
                    table_data.append(row)
        if table_data:
            df = pd.DataFrame(table_data)
            # Format numeric columns
            numeric_cols = ['Final Reward', 'Maximum Reward', 'Improvement', 'Test Reward']
            for col in numeric_cols:
                if col in df.columns:
                    df[col] = df[col].round(4)
            return df
        else:
            return pd.DataFrame()
    def _smooth_curve(self, values: List[float], window: int = 10) -> List[float]:
        """Smooth curve with moving average"""
        if len(values) < window:
            return values
        smoothed = []
        for i in range(len(values)):
            start_idx = max(0, i - window // 2)
            end_idx = min(len(values), i + window // 2 + 1)
            smoothed.append(np.mean(values[start_idx:end_idx]))
        return smoothed
    def _rolling_std(self, values: List[float], window: int = 10) -> List[float]:
        """Rolling standard deviation"""
        if len(values) < window:
            return [0.1] * len(values)
        rolling_std = []
        for i in range(len(values)):
            start_idx = max(0, i - window // 2)
            end_idx = min(len(values), i + window // 2 + 1)
            rolling_std.append(max(0.01, np.std(values[start_idx:end_idx])))
        return rolling_std
# ===== MAIN EXPERIMENT FUNCTION =====
def run_enhanced_experiment(quick_test: bool = False, use_real_data: bool = False):
    """Run enhanced experiment with visualization"""
    print(f"\
🔥 STARTING EXPERIMENT")
    print("=" * 70)
    # Check dependencies
    if 'DemographyEnv' not in globals() or 'EnhancedTrainer' not in globals():
        print("❌ CRITICAL ERROR: DemographyEnv or EnhancedTrainer classes not found")
        print("📋 Need to run files 1 and 2 in previous cells first")
        return {}, {}, pd.DataFrame()
    # Prepare data
    if use_real_data:
        try:
            df = pd.read_csv('regions_data_selective.csv')
            print("✅ Loaded real data")
            feature_cols = ['population', 'birth_rate', 'death_rate', 'natural_increase_rate',
                           'migration_balance', 'gdp_per_capita', 'unemployment_rate', 'average_wage']
            # Normalization
            for col in feature_cols:
                if col in df.columns:
                    df[col] = df.groupby('region_name')[col].transform(
                        lambda x: x.fillna(x.median())
                    )
                    x = df[col].values.astype(float)
                    mean_val, std_val = np.mean(x), np.std(x) + 1e-6
                    df[col] = np.clip((x - mean_val) / std_val, -3.0, 3.0)
            # Deltas
            for col in feature_cols:
                if col in df.columns:
                    delta_col = f"delta_{col}"
                    df[delta_col] = df.groupby('region_name')[col].diff().fillna(0.0)
                    df[delta_col] = np.clip(df[delta_col], -1.0, 1.0)
            obs_cols = [col for col in feature_cols if col in df.columns]
            obs_cols += [f"delta_{col}" for col in feature_cols if col in df.columns]
        except FileNotFoundError:
            print("⚠️ Real data not found, using demo data")
            df, obs_cols = prepare_demo_data()
    else:
        df, obs_cols = prepare_demo_data()
    # Create components
    if 'SmartMonitor' in globals():
        monitor = SmartMonitor()
        monitor.start()
    else:
        monitor = None
        print("⚠️ SmartMonitor not found, continuing without monitoring")
    # Set epochs
    if quick_test:
        training_epochs = 200
        testing_epochs = 20
        mode = "QUICK TEST"
    else:
        training_epochs = CONFIG['training_epochs']
        testing_epochs = CONFIG['testing_epochs']
        mode = "FULL EXPERIMENT"
    print(f"\
🎯 LAUNCH: {mode}")
    print(f"📊 Training: {training_epochs} epochs | Testing: {testing_epochs} epochs")
    print("=" * 70)
    print("✅ Enhanced implementation with fixes:")
    print("  • Fixed all imports and tqdm errors")
    print("  • Removed duplicate messages")
    print("  • Added testing phase")
    print("  • Improved DGM based on Darwin-Gödel Machine idea")
    print("  • Honest reward function")
    print("  • Detailed visualization with error handling")
    print("=" * 70)
    # Create environment and trainer
    try:
        env = DemographyEnv(df, obs_cols)
        trainer = EnhancedTrainer(env)
    except Exception as e:
        print(f"❌ CRITICAL ERROR creating environment/trainer: {e}")
        return {}, {}, pd.DataFrame()
    # Algorithms for comparison
    algorithms = ['MADDPG', 'MADDPG-EVO', 'MADDPG-EVO-DGM']
    results = {}
    # Run experiments
    for algorithm in algorithms:
        try:
            print(f"\
🔄 Preparing {algorithm}...")
            train_rewards, test_rewards = trainer.train_algorithm(
                algorithm, training_epochs, testing_epochs
            )
            results[algorithm] = (train_rewards, test_rewards)
        except Exception as e:
            print(f"❌ Critical error in {algorithm}: {str(e)}")
            # Add empty results to continue
            results[algorithm] = ([], [])
    # Analysis and visualization
    print(f"\
🎨 CREATING VISUALIZATION")
    print("=" * 50)
    visualizer = ExperimentVisualizer()
    # 1. Training curves
    print("📈 Training curves plot...")
    visualizer.plot_training_curves(results)
    # 2. Results table
    print("📊 Results table...")
    results_table = visualizer.create_results_table(results)
    if not results_table.empty:
        print(results_table.to_string(index=False))
    else:
        print("❌ No data for results table")
    # 3. Algorithm comparison
    print("\
🏆 Final comparison...")
    final_scores = {}
    for algorithm, (train_rewards, test_rewards) in results.items():
        if train_rewards:
            clean_rewards = [r for r in train_rewards if not np.isnan(r) and not np.isinf(r)]
            if clean_rewards:
                final_scores[algorithm] = np.mean(clean_rewards[-20:]) if len(clean_rewards) >= 20 else np.mean(clean_rewards)
            else:
                final_scores[algorithm] = 0.0
        else:
            final_scores[algorithm] = 0.0
    visualizer.plot_algorithm_comparison(final_scores)
    # 4. Algorithm evaluation
    print(f"\
🎯 ALGORITHM EVALUATION:")
    print("-" * 50)
    sorted_scores = sorted(final_scores.items(), key=lambda x: x[1], reverse=True)
    for i, (algorithm, score) in enumerate(sorted_scores, 1):
        status = "🥇" if i == 1 else "🥈" if i == 2 else "🥉" if i == 3 else f"{i}."
        print(f"{status} {algorithm}: {score:.4f}")
    # Final values
    maddpg_score = final_scores.get('MADDPG', 0)
    evo_score = final_scores.get('MADDPG-EVO', 0)
    dgm_score = final_scores.get('MADDPG-EVO-DGM', 0)
    # Print results
    print(f"MADDPG Score: {maddpg_score}")
    print(f"MADDPG-EVO Score: {evo_score}")
    print(f"MADDPG-EVO-DGM Score: {dgm_score}")
    # Final summary
    if monitor:
        monitor.summary()
    print(f"\
🎉 {mode} COMPLETED!")
    if any(final_scores.values()):
        print("📊 Graphs and tables created")
        print("🔬 algorithm comparison completed")
    else:
        print("⚠️ Experiment completed, but algorithms showed no results")
        print("🔧 Recommended to check settings and repeat training")
    return results, final_scores, results_table
# ===== RUN COMMANDS =====
print("\
✅ MADDPG EXPERIMENT RUNNER V1.1 - Ready to run!")
print("🔧 FIXED: all imports, tqdm, error handling, stability")
if 'DemographyEnv' in globals() and 'EnhancedTrainer' in globals():
    print("\
🔥 ALL COMPONENTS AVAILABLE - CAN RUN!")
    print("\
📋 RUN COMMANDS:")
    print("# Quick test (recommended for first run):")
    print("results, scores, table = run_enhanced_experiment(quick_test=True)")
    print("\
# Full experiment:")
    print("results, scores, table = run_enhanced_experiment(quick_test=False)")
    print("\
# With real data (if available):")
    print("results, scores, table = run_enhanced_experiment(quick_test=False, use_real_data=True)")
    print("\
🎯 AUTO-RUN QUICK TEST:")
    print("="*50)
    # Auto-run quick test
    try:
        results, scores, table = run_enhanced_experiment(quick_test=True)
        print("\
✅ Quick test completed successfully!")
    except Exception as e:
        print(f"❌ Error in auto-run: {e}")
        print("\
🔧 Run experiment manually with command:")
        print("results, scores, table = run_enhanced_experiment(quick_test=True)")
else:
    print("\
❌ NOT ALL COMPONENTS AVAILABLE")
    print("📋 Need to run files 1 and 2 first:")
    print("1. Run maddpg_core_fixed.py")
    print("2. Run maddpg_trainer_fixed.py")
    print("3. Then run this file")
    print("\
🔧 Or run experiment with base components:")
    print("results, scores, table = run_enhanced_experiment(quick_test=True)")
results, scores, table = run_enhanced_experiment(use_real_data=True)
# Out:
# 🚀 MADDPG CORE V1.1 - FIXED VERSION
# 📱 Device: cpu
# 🎯 Seed: 42
# ✅ MADDPG CORE V1.1 - All basic components loaded
# 🔧 FIXED: imports, tqdm fallback, error handling
# 📦 Available: Actor, Critic, MADDPGAgent, ReplayBuffer, EnhancedEvolution, AdvancedDGM
# 🎯 reward function: calculate_honest_reward
# ⚙️ Configuration: CONFIG
# 🚀 MADDPG TRAINER V1.1 - FIXED VERSION
# 📊 tqdm import and error handling
# ✅ MADDPG TRAINER V1.1 - All components loaded
# 🔧 FIXED: tqdm import, fallback functions, error handling
# 📦 Available: SmartMonitor, DemographyEnv, EnhancedTrainer
# 🎯 Ready to run experiments
# 🚀 MADDPG EXPERIMENT RUNNER V1.1 - FIXED VERSION
# 📊 All imports and components fixed
# ✅ MADDPG EXPERIMENT RUNNER V1.1 - Ready to run!
# 🔧 FIXED: all imports, tqdm, error handling, stability
# 🔥 ALL COMPONENTS AVAILABLE - CAN RUN!
# 📋 RUN COMMANDS:
# # Quick test (recommended for first run):
# results, scores, table = run_enhanced_experiment(quick_test=True)
# # Full experiment:
# results, scores, table = run_enhanced_experiment(quick_test=False)
# # With real data (if available):
# results, scores, table = run_enhanced_experiment(quick_test=False, use_real_data=True)
# 🎯 AUTO-RUN QUICK TEST:
# ==================================================
# 🔥 STARTING EXPERIMENT
# ======================================================================
# 📊 Preparing demo data...
# ✅ Prepared: 384 records, 16 regions, 24 years
# ⏰ Experiment started: 2025-10-13_09-35-59
# 🎯 LAUNCH: QUICK TEST
# 📊 Training: 200 epochs | Testing: 20 epochs
# ======================================================================
# ✅ Enhanced implementation with fixes:
#   • Fixed all imports and tqdm errors
#   • Removed duplicate messages
#   • Added testing phase
#   • Improved DGM based on Darwin-Gödel Machine idea
#   • Honest reward function
#   • Detailed visualization with error handling
# ======================================================================
# 🌍 Environment: 16 regions, 24 years
# 📊 State: 16D, Actions: 4D
# 🎯 Trainer created: state 16D, actions 4D
# 🔄 Preparing MADDPG...
# 🚀 TRAINING MADDPG
# 📊 Training: 200 epochs | Testing: 20 epochs
# ============================================================
# 🎓 TRAINING PHASE
# MADDPG Training:   0%|          | 0/200 [00:00<?, ?it/s]
# ✅ Created 5 agents for regions
# [MADDPG] Epoch 10/200: reward=30.128, regions=5, noise=0.294
#   📊 Metrics: actor_loss=-1.1420, critic_loss=41.8225, avg_q=1.498
# [MADDPG] Epoch 20/200: reward=28.534, regions=5, noise=0.288
#   📊 Metrics: actor_loss=-3.7665, critic_loss=10.0190, avg_q=4.071
# [MADDPG] Epoch 30/200: reward=28.166, regions=5, noise=0.283
#   📊 Metrics: actor_loss=-3.8268, critic_loss=4.4130, avg_q=3.695
# [MADDPG] Epoch 40/200: reward=29.112, regions=5, noise=0.277
#   📊 Metrics: actor_loss=-3.6788, critic_loss=8.9368, avg_q=3.818
# [MADDPG] Epoch 50/200: reward=28.717, regions=5, noise=0.271
#   📊 Metrics: actor_loss=-3.5389, critic_loss=4.0171, avg_q=3.429
# [MADDPG] Epoch 60/200: reward=31.944, regions=6, noise=0.266
#   📊 Metrics: actor_loss=-3.6569, critic_loss=4.4717, avg_q=3.300
# [MADDPG] Epoch 70/200: reward=34.812, regions=6, noise=0.261
#   📊 Metrics: actor_loss=-3.7203, critic_loss=3.3526, avg_q=3.495
# [MADDPG] Epoch 80/200: reward=34.281, regions=6, noise=0.256
#   📊 Metrics: actor_loss=-4.7611, critic_loss=2.8519, avg_q=4.548
# [MADDPG] Epoch 90/200: reward=35.316, regions=6, noise=0.251
#   📊 Metrics: actor_loss=-3.9504, critic_loss=2.7119, avg_q=3.605
# [MADDPG] Epoch 100/200: reward=36.210, regions=6, noise=0.246
#   📊 Metrics: actor_loss=-4.0876, critic_loss=2.3448, avg_q=3.708
# [MADDPG] Epoch 110/200: reward=34.306, regions=6, noise=0.241
#   📊 Metrics: actor_loss=-4.2047, critic_loss=2.6357, avg_q=4.015
# [MADDPG] Epoch 120/200: reward=43.163, regions=7, noise=0.236
#   📊 Metrics: actor_loss=-4.1094, critic_loss=4.3936, avg_q=4.199
# [MADDPG] Epoch 130/200: reward=41.871, regions=7, noise=0.231
#   📊 Metrics: actor_loss=-4.8643, critic_loss=1.9896, avg_q=4.506
# [MADDPG] Epoch 140/200: reward=42.123, regions=7, noise=0.227
#   📊 Metrics: actor_loss=-4.2275, critic_loss=2.1451, avg_q=4.067
# [MADDPG] Epoch 150/200: reward=42.414, regions=7, noise=0.222
#   📊 Metrics: actor_loss=-4.4265, critic_loss=3.6740, avg_q=4.454
# [MADDPG] Epoch 160/200: reward=42.979, regions=7, noise=0.218
#   📊 Metrics: actor_loss=-4.4954, critic_loss=1.6215, avg_q=4.196
# [MADDPG] Epoch 170/200: reward=47.417, regions=8, noise=0.213
#   📊 Metrics: actor_loss=-4.2334, critic_loss=2.6455, avg_q=3.852
# [MADDPG] Epoch 180/200: reward=49.751, regions=8, noise=0.209
#   📊 Metrics: actor_loss=-4.1368, critic_loss=2.4995, avg_q=4.168
# [MADDPG] Epoch 190/200: reward=48.755, regions=8, noise=0.205
#   📊 Metrics: actor_loss=-4.2547, critic_loss=1.6658, avg_q=3.787
# [MADDPG] Epoch 200/200: reward=49.467, regions=8, noise=0.201
#   📊 Metrics: actor_loss=-4.4618, critic_loss=1.4032, avg_q=4.498
# 🧪 TESTING PHASE (20 epochs)
# MADDPG Testing:   0%|          | 0/20 [00:00<?, ?it/s]
# ✅ MADDPG - TRAINING COMPLETED:
#   📊 Final reward: 49.1110
#   📈 Maximum reward: 55.1024
#   📊 Overall improvement: 18.1124
#   🧪 Test reward: 49.5203
#   🧪 Max in test: 58.7398
#   📊 Stability: 1.008
#   🤖 Trained agents: 8
#   💾 Total experience: 19065
# 🔄 Preparing MADDPG-EVO...
# 🚀 TRAINING MADDPG-EVO
# 📊 Training: 200 epochs | Testing: 20 epochs
# ============================================================
# 🎓 TRAINING PHASE
# MADDPG-EVO Training:   0%|          | 0/200 [00:00<?, ?it/s]
# 🧬 Evolution G1: 4 mutations, improvement: 0.0120
# [MADDPG-EVO] Epoch 10/200: reward=27.569, regions=5, noise=0.294
#   📊 Metrics: actor_loss=-0.8741, critic_loss=49.2811, avg_q=1.158
# 🧬 Evolution G2: 4 mutations, improvement: 0.0078
# [MADDPG-EVO] Epoch 20/200: reward=28.325, regions=5, noise=0.288
#   📊 Metrics: actor_loss=-2.6053, critic_loss=6.4815, avg_q=2.848
# [MADDPG-EVO] Epoch 30/200: reward=29.169, regions=5, noise=0.283
#   📊 Metrics: actor_loss=-3.1691, critic_loss=4.7707, avg_q=2.862
# 🧬 Evolution G3: 4 mutations, improvement: 0.0116
# [MADDPG-EVO] Epoch 40/200: reward=29.275, regions=5, noise=0.277
#   📊 Metrics: actor_loss=-2.8168, critic_loss=3.9903, avg_q=2.865
# 🧬 Evolution G4: 4 mutations, improvement: 0.0077
# [MADDPG-EVO] Epoch 50/200: reward=27.224, regions=5, noise=0.271
#   📊 Metrics: actor_loss=-3.7933, critic_loss=4.3554, avg_q=3.650
# [MADDPG-EVO] Epoch 60/200: reward=29.892, regions=6, noise=0.266
#   📊 Metrics: actor_loss=-3.1622, critic_loss=3.1193, avg_q=2.858
# 🧬 Evolution G5: 5 mutations, improvement: 0.0092
# [MADDPG-EVO] Epoch 70/200: reward=35.192, regions=6, noise=0.261
#   📊 Metrics: actor_loss=-3.3515, critic_loss=2.9737, avg_q=3.121
# 🧬 Evolution G6: 5 mutations, improvement: 0.0092
# [MADDPG-EVO] Epoch 80/200: reward=33.508, regions=6, noise=0.256
#   📊 Metrics: actor_loss=-4.1326, critic_loss=3.3060, avg_q=3.716
# [MADDPG-EVO] Epoch 90/200: reward=34.197, regions=6, noise=0.251
#   📊 Metrics: actor_loss=-3.2467, critic_loss=3.1698, avg_q=2.944
# 🧬 Evolution G7: 5 mutations, improvement: 0.0075
# [MADDPG-EVO] Epoch 100/200: reward=35.122, regions=6, noise=0.246
#   📊 Metrics: actor_loss=-5.0741, critic_loss=2.7901, avg_q=5.024
# 🧬 Evolution G8: 5 mutations, improvement: 0.0060
# [MADDPG-EVO] Epoch 110/200: reward=34.214, regions=6, noise=0.241
#   📊 Metrics: actor_loss=-3.5385, critic_loss=3.2722, avg_q=3.074
# [MADDPG-EVO] Epoch 120/200: reward=40.371, regions=7, noise=0.236
#   📊 Metrics: actor_loss=-3.8701, critic_loss=3.2967, avg_q=3.416
# 🧬 Evolution G9: 5 mutations, improvement: 0.0117
# [MADDPG-EVO] Epoch 130/200: reward=42.639, regions=7, noise=0.231
#   📊 Metrics: actor_loss=-3.4415, critic_loss=2.8927, avg_q=3.372
# 🧬 Evolution G10: 5 mutations, improvement: 0.0084
# [MADDPG-EVO] Epoch 140/200: reward=40.116, regions=7, noise=0.227
#   📊 Metrics: actor_loss=-4.3292, critic_loss=1.2926, avg_q=3.900
# [MADDPG-EVO] Epoch 150/200: reward=41.709, regions=7, noise=0.222
#   📊 Metrics: actor_loss=-4.0952, critic_loss=1.5804, avg_q=3.992
# 🧬 Evolution G11: 5 mutations, improvement: 0.0114
# [MADDPG-EVO] Epoch 160/200: reward=42.818, regions=7, noise=0.218
#   📊 Metrics: actor_loss=-4.3407, critic_loss=3.3811, avg_q=4.159
# 🧬 Evolution G12: 6 mutations, improvement: 0.0072
# [MADDPG-EVO] Epoch 170/200: reward=48.617, regions=8, noise=0.213
#   📊 Metrics: actor_loss=-4.4968, critic_loss=3.6101, avg_q=4.289
# [MADDPG-EVO] Epoch 180/200: reward=50.083, regions=8, noise=0.209
#   📊 Metrics: actor_loss=-4.1677, critic_loss=2.8823, avg_q=4.114
# 🧬 Evolution G13: 6 mutations, improvement: 0.0072
# [MADDPG-EVO] Epoch 190/200: reward=49.439, regions=8, noise=0.205
#   📊 Metrics: actor_loss=-4.5595, critic_loss=2.4616, avg_q=4.185
# 🧬 Evolution G14: 6 mutations, improvement: 0.0072
# [MADDPG-EVO] Epoch 200/200: reward=50.825, regions=8, noise=0.201
#   📊 Metrics: actor_loss=-4.2147, critic_loss=1.7938, avg_q=3.632
# 🧪 TESTING PHASE (20 epochs)
# MADDPG-EVO Testing:   0%|          | 0/20 [00:00<?, ?it/s]
# ✅ MADDPG-EVO - TRAINING COMPLETED:
#   📊 Final reward: 50.1318
#   📈 Maximum reward: 54.7789
#   📊 Overall improvement: 21.8128
#   🧪 Test reward: 51.7744
#   🧪 Max in test: 60.9263
#   📊 Stability: 1.033
#   🤖 Trained agents: 8
#   💾 Total experience: 19065
# 🔄 Preparing MADDPG-EVO-DGM...
# 🚀 TRAINING MADDPG-EVO-DGM
# 📊 Training: 200 epochs | Testing: 20 epochs
# ============================================================
# 🎓 TRAINING PHASE
# MADDPG-EVO-DGM Training:   0%|          | 0/200 [00:00<?, ?it/s]
# 🧬 Evolution G1: 4 mutations, improvement: 0.0121
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 10/200: reward=28.908, regions=5, noise=0.294
#   📊 Metrics: actor_loss=-1.2555, critic_loss=52.9137, avg_q=1.615
# 🧬 Evolution G2: 4 mutations, improvement: 0.0037
# [MADDPG-EVO-DGM] Epoch 20/200: reward=30.003, regions=5, noise=0.288
#   📊 Metrics: actor_loss=-3.7517, critic_loss=11.4523, avg_q=4.030
# [MADDPG-EVO-DGM] Epoch 30/200: reward=29.111, regions=5, noise=0.283
#   📊 Metrics: actor_loss=-4.0750, critic_loss=5.2106, avg_q=4.000
# 🧬 Evolution G3: 4 mutations, improvement: 0.0040
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 40/200: reward=28.986, regions=5, noise=0.277
#   📊 Metrics: actor_loss=-4.1590, critic_loss=3.1163, avg_q=4.107
# 🧬 Evolution G4: 4 mutations, improvement: 0.0117
# [MADDPG-EVO-DGM] Epoch 50/200: reward=28.928, regions=5, noise=0.271
#   📊 Metrics: actor_loss=-3.5991, critic_loss=2.6117, avg_q=3.523
# [MADDPG-EVO-DGM] Epoch 60/200: reward=32.012, regions=6, noise=0.266
#   📊 Metrics: actor_loss=-3.9107, critic_loss=3.7881, avg_q=3.845
# 🧬 Evolution G5: 5 mutations, improvement: 0.0061
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 70/200: reward=35.523, regions=6, noise=0.261
#   📊 Metrics: actor_loss=-3.8976, critic_loss=1.7547, avg_q=3.845
# 🧬 Evolution G6: 5 mutations, improvement: 0.0059
# [MADDPG-EVO-DGM] Epoch 80/200: reward=34.810, regions=6, noise=0.256
#   📊 Metrics: actor_loss=-4.0235, critic_loss=3.5913, avg_q=3.867
# [MADDPG-EVO-DGM] Epoch 90/200: reward=35.355, regions=6, noise=0.251
#   📊 Metrics: actor_loss=-4.0549, critic_loss=2.7671, avg_q=3.961
# 🧬 Evolution G7: 5 mutations, improvement: 0.0079
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 100/200: reward=35.586, regions=6, noise=0.246
#   📊 Metrics: actor_loss=-3.9559, critic_loss=1.5379, avg_q=3.888
# 🧬 Evolution G8: 5 mutations, improvement: 0.0146
# [MADDPG-EVO-DGM] Epoch 110/200: reward=34.749, regions=6, noise=0.241
#   📊 Metrics: actor_loss=-4.3291, critic_loss=2.4149, avg_q=4.189
# [MADDPG-EVO-DGM] Epoch 120/200: reward=42.994, regions=7, noise=0.236
#   📊 Metrics: actor_loss=-4.0852, critic_loss=1.4941, avg_q=3.805
# 🧬 Evolution G9: 5 mutations, improvement: 0.0059
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 130/200: reward=43.089, regions=7, noise=0.231
#   📊 Metrics: actor_loss=-4.1271, critic_loss=2.8590, avg_q=4.005
# 🧬 Evolution G10: 5 mutations, improvement: 0.0083
# [MADDPG-EVO-DGM] Epoch 140/200: reward=43.804, regions=7, noise=0.227
#   📊 Metrics: actor_loss=-4.3523, critic_loss=1.6910, avg_q=3.994
# [MADDPG-EVO-DGM] Epoch 150/200: reward=41.967, regions=7, noise=0.222
#   📊 Metrics: actor_loss=-3.9082, critic_loss=1.8432, avg_q=3.712
# 🧬 Evolution G11: 5 mutations, improvement: 0.0115
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 160/200: reward=44.266, regions=7, noise=0.218
#   📊 Metrics: actor_loss=-3.9756, critic_loss=2.0314, avg_q=3.847
# 🧬 Evolution G12: 6 mutations, improvement: 0.0057
# [MADDPG-EVO-DGM] Epoch 170/200: reward=48.111, regions=8, noise=0.213
#   📊 Metrics: actor_loss=-4.2271, critic_loss=1.8620, avg_q=4.027
# [MADDPG-EVO-DGM] Epoch 180/200: reward=52.700, regions=8, noise=0.209
#   📊 Metrics: actor_loss=-4.6752, critic_loss=1.8538, avg_q=4.503
# 🧬 Evolution G13: 6 mutations, improvement: 0.0071
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 190/200: reward=49.548, regions=8, noise=0.205
#   📊 Metrics: actor_loss=-4.5473, critic_loss=2.5579, avg_q=4.197
# 🧬 Evolution G14: 6 mutations, improvement: 0.0062
# [MADDPG-EVO-DGM] Epoch 200/200: reward=51.495, regions=8, noise=0.201
#   📊 Metrics: actor_loss=-4.5753, critic_loss=3.1022, avg_q=4.490
# 🧪 TESTING PHASE (20 epochs)
# MADDPG-EVO-DGM Testing:   0%|          | 0/20 [00:00<?, ?it/s]
# ✅ MADDPG-EVO-DGM - TRAINING COMPLETED:
#   📊 Final reward: 50.5217
#   📈 Maximum reward: 57.0079
#   📊 Overall improvement: 25.0266
#   🧪 Test reward: 51.4168
#   🧪 Max in test: 64.8136
#   📊 Stability: 1.018
#   🤖 Trained agents: 8
#   💾 Total experience: 19065
# 🎨 CREATING VISUALIZATION
# ==================================================
# 📈 Training curves plot...
# 📊 Results table...
#      Algorithm  Final Reward  Maximum Reward  Standard Deviation  Improvement  Stability  Training Epochs  Test Reward  Generalization  Testing Epochs
#         MADDPG       49.1110         55.1024            8.023482      18.1124   4.774899              200      49.5203        1.008333              20
#     MADDPG-EVO       50.1318         54.7789            8.377426      21.8128   4.517047              200      51.7744        1.032765              20
# MADDPG-EVO-DGM       50.5217         57.0079            8.360278      25.0266   4.410589              200      51.4168        1.017716              20
# 🏆 Final comparison...
# 🎯 ALGORITHM EVALUATION:
# --------------------------------------------------
# 🥇 MADDPG-EVO-DGM: 50.5217
# 🥈 MADDPG-EVO: 50.1318
# 🥉 MADDPG: 49.1110
# MADDPG Score: 49.11104640035863
# MADDPG-EVO Score: 50.13184195460186
# MADDPG-EVO-DGM Score: 50.52172616497403
# 🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆
# TRAINING RESULTS
# 🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆
# 🎉 QUICK TEST COMPLETED!
# 📊 Graphs and tables created
# 🔬 algorithm comparison completed
# ✅ Quick test completed successfully!
# 🔥 STARTING EXPERIMENT
# ======================================================================
# ✅ Loaded real data
# ⏰ Experiment started: 2025-10-13_09-40-43
# 🎯 LAUNCH: FULL EXPERIMENT
# 📊 Training: 1000 epochs | Testing: 200 epochs
# ======================================================================
# ✅ Enhanced implementation with fixes:
#   • Fixed all imports and tqdm errors
#   • Removed duplicate messages
#   • Added testing phase
#   • Improved DGM based on Darwin-Gödel Machine idea
#   • Honest reward function
#   • Detailed visualization with error handling
# ======================================================================
# 🌍 Environment: 86 regions, 36 years
# 📊 State: 16D, Actions: 4D
# 🎯 Trainer created: state 16D, actions 4D
# 🔄 Preparing MADDPG...
# 🚀 TRAINING MADDPG
# 📊 Training: 1000 epochs | Testing: 200 epochs
# ============================================================
# 🎓 TRAINING PHASE
# MADDPG Training:   0%|          | 0/1000 [00:00<?, ?it/s]
# ✅ Created 5 agents for regions
# [MADDPG] Epoch 10/1000: reward=11.113, regions=6, noise=0.294
#   📊 Metrics: actor_loss=-1.6568, critic_loss=0.4057, avg_q=2.128
# [MADDPG] Epoch 20/1000: reward=13.685, regions=7, noise=0.288
#   📊 Metrics: actor_loss=-2.0851, critic_loss=0.2132, avg_q=2.193
# [MADDPG] Epoch 30/1000: reward=15.901, regions=8, noise=0.283
#   📊 Metrics: actor_loss=-2.0594, critic_loss=0.1568, avg_q=2.135
# ✅ Created 10 agents for regions
# [MADDPG] Epoch 40/1000: reward=18.422, regions=10, noise=0.277
#   📊 Metrics: actor_loss=-2.0512, critic_loss=0.1190, avg_q=2.091
# [MADDPG] Epoch 50/1000: reward=20.532, regions=11, noise=0.271
#   📊 Metrics: actor_loss=-2.1212, critic_loss=0.1183, avg_q=2.131
# [MADDPG] Epoch 60/1000: reward=22.493, regions=12, noise=0.266
#   📊 Metrics: actor_loss=-2.1246, critic_loss=0.1302, avg_q=2.112
# [MADDPG] Epoch 70/1000: reward=25.522, regions=14, noise=0.261
#   📊 Metrics: actor_loss=-2.0157, critic_loss=0.1017, avg_q=2.028
# [MADDPG] Epoch 80/1000: reward=27.013, regions=15, noise=0.256
#   📊 Metrics: actor_loss=-1.9775, critic_loss=0.1091, avg_q=1.907
# [MADDPG] Epoch 90/1000: reward=29.957, regions=17, noise=0.251
#   📊 Metrics: actor_loss=-2.0934, critic_loss=0.0814, avg_q=2.048
# [MADDPG] Epoch 100/1000: reward=31.961, regions=18, noise=0.246
#   📊 Metrics: actor_loss=-2.0288, critic_loss=0.0867, avg_q=1.972
# [MADDPG] Epoch 110/1000: reward=33.808, regions=19, noise=0.241
#   📊 Metrics: actor_loss=-2.0505, critic_loss=0.0962, avg_q=1.902
# ✅ Created 20 agents for regions
# [MADDPG] Epoch 120/1000: reward=36.319, regions=21, noise=0.236
#   📊 Metrics: actor_loss=-2.0409, critic_loss=0.1021, avg_q=1.813
# [MADDPG] Epoch 130/1000: reward=38.301, regions=22, noise=0.231
#   📊 Metrics: actor_loss=-2.1072, critic_loss=0.0763, avg_q=1.993
# [MADDPG] Epoch 140/1000: reward=39.977, regions=23, noise=0.227
#   📊 Metrics: actor_loss=-2.1137, critic_loss=0.0942, avg_q=1.925
# [MADDPG] Epoch 150/1000: reward=41.076, regions=25, noise=0.222
#   📊 Metrics: actor_loss=-2.1344, critic_loss=0.0822, avg_q=1.941
# [MADDPG] Epoch 160/1000: reward=43.539, regions=26, noise=0.218
#   📊 Metrics: actor_loss=-2.1659, critic_loss=0.0865, avg_q=2.036
# [MADDPG] Epoch 170/1000: reward=45.236, regions=27, noise=0.213
#   📊 Metrics: actor_loss=-2.1416, critic_loss=0.0930, avg_q=2.027
# [MADDPG] Epoch 180/1000: reward=47.279, regions=29, noise=0.209
#   📊 Metrics: actor_loss=-2.1549, critic_loss=0.0776, avg_q=1.993
# ✅ Created 30 agents for regions
# [MADDPG] Epoch 190/1000: reward=48.897, regions=30, noise=0.205
#   📊 Metrics: actor_loss=-2.1446, critic_loss=0.0827, avg_q=2.028
# [MADDPG] Epoch 200/1000: reward=49.966, regions=31, noise=0.201
#   📊 Metrics: actor_loss=-2.1247, critic_loss=0.0883, avg_q=1.994
# [MADDPG] Epoch 210/1000: reward=52.428, regions=33, noise=0.197
#   📊 Metrics: actor_loss=-2.0740, critic_loss=0.0845, avg_q=1.989
# [MADDPG] Epoch 220/1000: reward=54.183, regions=34, noise=0.193
#   📊 Metrics: actor_loss=-2.1036, critic_loss=0.0825, avg_q=1.974
# [MADDPG] Epoch 230/1000: reward=54.836, regions=35, noise=0.189
#   📊 Metrics: actor_loss=-2.0574, critic_loss=0.1128, avg_q=1.914
# [MADDPG] Epoch 240/1000: reward=57.769, regions=37, noise=0.186
#   📊 Metrics: actor_loss=-2.0523, critic_loss=0.0921, avg_q=1.966
# [MADDPG] Epoch 250/1000: reward=58.351, regions=38, noise=0.182
#   📊 Metrics: actor_loss=-2.0936, critic_loss=0.1346, avg_q=2.004
# [MADDPG] Epoch 260/1000: reward=60.873, regions=39, noise=0.178
#   📊 Metrics: actor_loss=-2.1090, critic_loss=0.0996, avg_q=2.064
# ✅ Created 40 agents for regions
# [MADDPG] Epoch 270/1000: reward=62.426, regions=41, noise=0.175
#   📊 Metrics: actor_loss=-2.0920, critic_loss=0.1262, avg_q=1.850
# [MADDPG] Epoch 280/1000: reward=64.491, regions=42, noise=0.171
#   📊 Metrics: actor_loss=-2.1055, critic_loss=0.1321, avg_q=2.018
# [MADDPG] Epoch 290/1000: reward=65.777, regions=44, noise=0.168
#   📊 Metrics: actor_loss=-2.2095, critic_loss=0.1168, avg_q=2.154
# [MADDPG] Epoch 300/1000: reward=68.555, regions=45, noise=0.165
#   📊 Metrics: actor_loss=-2.0750, critic_loss=0.1221, avg_q=2.031
# [MADDPG] Epoch 310/1000: reward=70.222, regions=46, noise=0.161
#   📊 Metrics: actor_loss=-2.1599, critic_loss=0.1123, avg_q=1.997
# [MADDPG] Epoch 320/1000: reward=71.651, regions=48, noise=0.158
#   📊 Metrics: actor_loss=-2.2058, critic_loss=0.1451, avg_q=2.156
# [MADDPG] Epoch 330/1000: reward=73.256, regions=49, noise=0.155
#   📊 Metrics: actor_loss=-2.2244, critic_loss=0.1455, avg_q=2.052
# ✅ Created 50 agents for regions
# [MADDPG] Epoch 340/1000: reward=73.208, regions=50, noise=0.152
#   📊 Metrics: actor_loss=-2.1670, critic_loss=0.1405, avg_q=2.058
# [MADDPG] Epoch 350/1000: reward=76.524, regions=52, noise=0.149
#   📊 Metrics: actor_loss=-2.2104, critic_loss=0.1143, avg_q=2.121
# [MADDPG] Epoch 360/1000: reward=78.497, regions=53, noise=0.146
#   📊 Metrics: actor_loss=-2.2278, critic_loss=0.1438, avg_q=2.172
# [MADDPG] Epoch 370/1000: reward=79.932, regions=54, noise=0.143
#   📊 Metrics: actor_loss=-2.1235, critic_loss=0.1659, avg_q=2.038
# [MADDPG] Epoch 380/1000: reward=82.360, regions=56, noise=0.140
#   📊 Metrics: actor_loss=-2.2312, critic_loss=0.1507, avg_q=2.123
# [MADDPG] Epoch 390/1000: reward=84.348, regions=57, noise=0.137
#   📊 Metrics: actor_loss=-2.3144, critic_loss=0.1684, avg_q=2.287
# [MADDPG] Epoch 400/1000: reward=86.120, regions=58, noise=0.135
#   📊 Metrics: actor_loss=-2.3243, critic_loss=0.1457, avg_q=2.194
# ✅ Created 60 agents for regions
# [MADDPG] Epoch 410/1000: reward=87.930, regions=60, noise=0.132
#   📊 Metrics: actor_loss=-2.3013, critic_loss=0.1394, avg_q=2.291
# [MADDPG] Epoch 420/1000: reward=89.088, regions=61, noise=0.129
#   📊 Metrics: actor_loss=-2.2832, critic_loss=0.2401, avg_q=2.255
# [MADDPG] Epoch 430/1000: reward=90.617, regions=62, noise=0.127
#   📊 Metrics: actor_loss=-2.3513, critic_loss=0.2058, avg_q=2.218
# [MADDPG] Epoch 440/1000: reward=92.304, regions=64, noise=0.124
#   📊 Metrics: actor_loss=-2.3163, critic_loss=0.2051, avg_q=2.219
# [MADDPG] Epoch 450/1000: reward=95.228, regions=65, noise=0.122
#   📊 Metrics: actor_loss=-2.4134, critic_loss=0.1833, avg_q=2.358
# [MADDPG] Epoch 460/1000: reward=96.788, regions=66, noise=0.119
#   📊 Metrics: actor_loss=-2.3948, critic_loss=0.2424, avg_q=2.336
# [MADDPG] Epoch 470/1000: reward=98.890, regions=68, noise=0.117
#   📊 Metrics: actor_loss=-2.4285, critic_loss=0.2095, avg_q=2.305
# [MADDPG] Epoch 480/1000: reward=100.053, regions=69, noise=0.115
#   📊 Metrics: actor_loss=-2.4945, critic_loss=0.2326, avg_q=2.396
# ✅ Created 70 agents for regions
# [MADDPG] Epoch 490/1000: reward=103.233, regions=71, noise=0.112
#   📊 Metrics: actor_loss=-2.4695, critic_loss=0.2440, avg_q=2.432
# [MADDPG] Epoch 500/1000: reward=104.708, regions=72, noise=0.110
#   📊 Metrics: actor_loss=-2.4707, critic_loss=0.3162, avg_q=2.439
# [MADDPG] Epoch 510/1000: reward=106.909, regions=73, noise=0.108
#   📊 Metrics: actor_loss=-2.4770, critic_loss=0.2725, avg_q=2.425
# [MADDPG] Epoch 520/1000: reward=107.840, regions=75, noise=0.106
#   📊 Metrics: actor_loss=-2.5560, critic_loss=0.2927, avg_q=2.461
# [MADDPG] Epoch 530/1000: reward=109.451, regions=76, noise=0.104
#   📊 Metrics: actor_loss=-2.5645, critic_loss=0.3234, avg_q=2.509
# [MADDPG] Epoch 540/1000: reward=111.720, regions=77, noise=0.102
#   📊 Metrics: actor_loss=-2.5262, critic_loss=0.3637, avg_q=2.402
# [MADDPG] Epoch 550/1000: reward=112.517, regions=79, noise=0.100
#   📊 Metrics: actor_loss=-2.5732, critic_loss=0.3249, avg_q=2.487
# ✅ Created 80 agents for regions
# [MADDPG] Epoch 560/1000: reward=112.978, regions=80, noise=0.098
#   📊 Metrics: actor_loss=-2.5804, critic_loss=0.3564, avg_q=2.516
# [MADDPG] Epoch 570/1000: reward=115.729, regions=81, noise=0.096
#   📊 Metrics: actor_loss=-2.6507, critic_loss=0.3655, avg_q=2.551
# [MADDPG] Epoch 580/1000: reward=117.414, regions=83, noise=0.094
#   📊 Metrics: actor_loss=-2.6103, critic_loss=0.4364, avg_q=2.458
# [MADDPG] Epoch 590/1000: reward=118.540, regions=84, noise=0.092
#   📊 Metrics: actor_loss=-2.6271, critic_loss=0.4457, avg_q=2.510
# [MADDPG] Epoch 600/1000: reward=120.704, regions=85, noise=0.090
#   📊 Metrics: actor_loss=-2.6623, critic_loss=0.4224, avg_q=2.600
# ✅ Created 86 agents for regions
# [MADDPG] Epoch 610/1000: reward=121.603, regions=86, noise=0.088
#   📊 Metrics: actor_loss=-2.6055, critic_loss=0.4865, avg_q=2.550
# [MADDPG] Epoch 620/1000: reward=120.996, regions=86, noise=0.087
#   📊 Metrics: actor_loss=-2.7808, critic_loss=0.4559, avg_q=2.645
# [MADDPG] Epoch 630/1000: reward=119.881, regions=86, noise=0.085
#   📊 Metrics: actor_loss=-2.7423, critic_loss=0.4523, avg_q=2.665
# [MADDPG] Epoch 640/1000: reward=118.679, regions=86, noise=0.083
#   📊 Metrics: actor_loss=-2.9181, critic_loss=0.4589, avg_q=2.841
# [MADDPG] Epoch 650/1000: reward=117.316, regions=86, noise=0.082
#   📊 Metrics: actor_loss=-2.7272, critic_loss=0.4958, avg_q=2.581
# [MADDPG] Epoch 660/1000: reward=118.981, regions=86, noise=0.080
#   📊 Metrics: actor_loss=-2.8632, critic_loss=0.5951, avg_q=2.748
# [MADDPG] Epoch 670/1000: reward=116.475, regions=86, noise=0.078
#   📊 Metrics: actor_loss=-2.8616, critic_loss=0.5613, avg_q=2.739
# [MADDPG] Epoch 680/1000: reward=116.935, regions=86, noise=0.077
#   📊 Metrics: actor_loss=-2.8885, critic_loss=0.6134, avg_q=2.779
# [MADDPG] Epoch 690/1000: reward=114.277, regions=86, noise=0.075
#   📊 Metrics: actor_loss=-2.8935, critic_loss=0.6432, avg_q=2.771
# [MADDPG] Epoch 700/1000: reward=112.297, regions=86, noise=0.074
#   📊 Metrics: actor_loss=-2.8390, critic_loss=0.6788, avg_q=2.690
# [MADDPG] Epoch 710/1000: reward=112.672, regions=86, noise=0.072
#   📊 Metrics: actor_loss=-2.8378, critic_loss=0.6852, avg_q=2.727
# [MADDPG] Epoch 720/1000: reward=108.471, regions=86, noise=0.071
#   📊 Metrics: actor_loss=-2.9902, critic_loss=0.7743, avg_q=2.811
# [MADDPG] Epoch 730/1000: reward=110.184, regions=86, noise=0.070
#   📊 Metrics: actor_loss=-2.9773, critic_loss=0.6429, avg_q=2.797
# [MADDPG] Epoch 740/1000: reward=108.355, regions=86, noise=0.068
#   📊 Metrics: actor_loss=-3.0068, critic_loss=0.6707, avg_q=2.879
# [MADDPG] Epoch 750/1000: reward=106.662, regions=86, noise=0.067
#   📊 Metrics: actor_loss=-3.0547, critic_loss=0.6437, avg_q=2.895
# [MADDPG] Epoch 760/1000: reward=105.213, regions=86, noise=0.066
#   📊 Metrics: actor_loss=-3.0891, critic_loss=0.7082, avg_q=2.930
# [MADDPG] Epoch 770/1000: reward=102.962, regions=86, noise=0.064
#   📊 Metrics: actor_loss=-3.0428, critic_loss=0.8490, avg_q=2.912
# [MADDPG] Epoch 780/1000: reward=102.094, regions=86, noise=0.063
#   📊 Metrics: actor_loss=-3.0701, critic_loss=0.8719, avg_q=2.819
# [MADDPG] Epoch 790/1000: reward=100.570, regions=86, noise=0.062
#   📊 Metrics: actor_loss=-3.1326, critic_loss=0.7866, avg_q=2.947
# [MADDPG] Epoch 800/1000: reward=101.101, regions=86, noise=0.060
#   📊 Metrics: actor_loss=-3.1416, critic_loss=0.9578, avg_q=2.977
# [MADDPG] Epoch 810/1000: reward=99.076, regions=86, noise=0.059
#   📊 Metrics: actor_loss=-3.1744, critic_loss=0.8586, avg_q=2.973
# [MADDPG] Epoch 820/1000: reward=98.860, regions=86, noise=0.058
#   📊 Metrics: actor_loss=-3.1416, critic_loss=1.0647, avg_q=2.920
# [MADDPG] Epoch 830/1000: reward=98.754, regions=86, noise=0.057
#   📊 Metrics: actor_loss=-3.3051, critic_loss=0.8991, avg_q=3.074
# [MADDPG] Epoch 840/1000: reward=97.319, regions=86, noise=0.056
#   📊 Metrics: actor_loss=-3.1804, critic_loss=0.9838, avg_q=2.970
# [MADDPG] Epoch 850/1000: reward=96.648, regions=86, noise=0.055
#   📊 Metrics: actor_loss=-3.2020, critic_loss=0.9168, avg_q=2.967
# [MADDPG] Epoch 860/1000: reward=96.522, regions=86, noise=0.054
#   📊 Metrics: actor_loss=-3.1774, critic_loss=1.1128, avg_q=2.947
# [MADDPG] Epoch 870/1000: reward=96.049, regions=86, noise=0.053
#   📊 Metrics: actor_loss=-3.2704, critic_loss=1.1437, avg_q=3.026
# [MADDPG] Epoch 880/1000: reward=95.219, regions=86, noise=0.052
#   📊 Metrics: actor_loss=-3.3976, critic_loss=1.1096, avg_q=3.198
# [MADDPG] Epoch 890/1000: reward=96.585, regions=86, noise=0.051
#   📊 Metrics: actor_loss=-3.3367, critic_loss=1.1630, avg_q=3.045
# [MADDPG] Epoch 900/1000: reward=95.344, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-3.3416, critic_loss=1.0685, avg_q=3.040
# [MADDPG] Epoch 910/1000: reward=95.541, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-3.3766, critic_loss=1.1349, avg_q=3.043
# [MADDPG] Epoch 920/1000: reward=94.879, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-3.3046, critic_loss=1.3833, avg_q=3.126
# [MADDPG] Epoch 930/1000: reward=93.936, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-3.4256, critic_loss=1.3486, avg_q=3.185
# [MADDPG] Epoch 940/1000: reward=93.589, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-3.4598, critic_loss=0.9275, avg_q=3.201
# [MADDPG] Epoch 950/1000: reward=92.812, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-3.3415, critic_loss=1.3808, avg_q=3.169
# [MADDPG] Epoch 960/1000: reward=94.223, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-3.4892, critic_loss=1.3603, avg_q=3.229
# [MADDPG] Epoch 970/1000: reward=92.454, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-3.5620, critic_loss=1.3713, avg_q=3.362
# [MADDPG] Epoch 980/1000: reward=93.967, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-3.4971, critic_loss=1.4174, avg_q=3.243
# [MADDPG] Epoch 990/1000: reward=91.898, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-3.5428, critic_loss=1.6255, avg_q=3.295
# [MADDPG] Epoch 1000/1000: reward=91.616, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-3.4937, critic_loss=1.8178, avg_q=3.128
# 🧪 TESTING PHASE (200 epochs)
# MADDPG Testing:   0%|          | 0/200 [00:00<?, ?it/s]
# ✅ MADDPG - TRAINING COMPLETED:
#   📊 Final reward: 91.7569
#   📈 Maximum reward: 126.2302
#   📊 Overall improvement: 80.6447
#   🧪 Test reward: 92.6754
#   🧪 Max in test: 95.7958
#   📊 Stability: 1.010
#   🤖 Trained agents: 86
#   💾 Total experience: 920415
# 🔄 Preparing MADDPG-EVO...
# 🚀 TRAINING MADDPG-EVO
# 📊 Training: 1000 epochs | Testing: 200 epochs
# ============================================================
# 🎓 TRAINING PHASE
# MADDPG-EVO Training:   0%|          | 0/1000 [00:00<?, ?it/s]
# 🧬 Evolution G1: 4 mutations, improvement: 0.0156
# [MADDPG-EVO] Epoch 10/1000: reward=10.632, regions=6, noise=0.294
#   📊 Metrics: actor_loss=-1.5096, critic_loss=0.7179, avg_q=1.899
# 🧬 Evolution G2: 5 mutations, improvement: 0.0093
# [MADDPG-EVO] Epoch 20/1000: reward=13.442, regions=7, noise=0.288
#   📊 Metrics: actor_loss=-1.8126, critic_loss=0.2010, avg_q=1.841
# [MADDPG-EVO] Epoch 30/1000: reward=15.830, regions=8, noise=0.283
#   📊 Metrics: actor_loss=-1.7447, critic_loss=0.1327, avg_q=1.757
# 🧬 Evolution G3: 7 mutations, improvement: 0.0087
# [MADDPG-EVO] Epoch 40/1000: reward=18.144, regions=10, noise=0.277
#   📊 Metrics: actor_loss=-1.7984, critic_loss=0.1303, avg_q=1.802
# 🧬 Evolution G4: 8 mutations, improvement: 0.0097
# [MADDPG-EVO] Epoch 50/1000: reward=21.231, regions=11, noise=0.271
#   📊 Metrics: actor_loss=-1.8168, critic_loss=0.1147, avg_q=1.772
# [MADDPG-EVO] Epoch 60/1000: reward=23.147, regions=12, noise=0.266
#   📊 Metrics: actor_loss=-1.9376, critic_loss=0.1461, avg_q=1.892
# 🧬 Evolution G5: 10 mutations, improvement: 0.0061
# [MADDPG-EVO] Epoch 70/1000: reward=25.882, regions=14, noise=0.261
#   📊 Metrics: actor_loss=-1.8430, critic_loss=0.0996, avg_q=1.687
# 🧬 Evolution G6: 11 mutations, improvement: 0.0083
# [MADDPG-EVO] Epoch 80/1000: reward=28.020, regions=15, noise=0.256
#   📊 Metrics: actor_loss=-1.8682, critic_loss=0.0929, avg_q=1.748
# [MADDPG-EVO] Epoch 90/1000: reward=29.403, regions=17, noise=0.251
#   📊 Metrics: actor_loss=-1.7910, critic_loss=0.0666, avg_q=1.601
# 🧬 Evolution G7: 12 mutations, improvement: 0.0108
# [MADDPG-EVO] Epoch 100/1000: reward=31.909, regions=18, noise=0.246
#   📊 Metrics: actor_loss=-1.8990, critic_loss=0.0793, avg_q=1.777
# 🧬 Evolution G8: 14 mutations, improvement: 0.0053
# [MADDPG-EVO] Epoch 110/1000: reward=34.666, regions=19, noise=0.241
#   📊 Metrics: actor_loss=-1.7995, critic_loss=0.0905, avg_q=1.636
# [MADDPG-EVO] Epoch 120/1000: reward=36.719, regions=21, noise=0.236
#   📊 Metrics: actor_loss=-1.7334, critic_loss=0.1011, avg_q=1.610
# 🧬 Evolution G9: 15 mutations, improvement: 0.0135
# [MADDPG-EVO] Epoch 130/1000: reward=38.875, regions=22, noise=0.231
#   📊 Metrics: actor_loss=-1.8106, critic_loss=0.0948, avg_q=1.643
# 🧬 Evolution G10: 17 mutations, improvement: 0.0059
# [MADDPG-EVO] Epoch 140/1000: reward=40.210, regions=23, noise=0.227
#   📊 Metrics: actor_loss=-1.7854, critic_loss=0.0904, avg_q=1.546
# [MADDPG-EVO] Epoch 150/1000: reward=42.867, regions=25, noise=0.222
#   📊 Metrics: actor_loss=-1.7079, critic_loss=0.1219, avg_q=1.620
# 🧬 Evolution G11: 18 mutations, improvement: 0.0083
# [MADDPG-EVO] Epoch 160/1000: reward=44.966, regions=26, noise=0.218
#   📊 Metrics: actor_loss=-1.7469, critic_loss=0.1116, avg_q=1.658
# 🧬 Evolution G12: 19 mutations, improvement: 0.0116
# [MADDPG-EVO] Epoch 170/1000: reward=46.647, regions=27, noise=0.213
#   📊 Metrics: actor_loss=-1.8131, critic_loss=0.1111, avg_q=1.737
# [MADDPG-EVO] Epoch 180/1000: reward=49.501, regions=29, noise=0.209
#   📊 Metrics: actor_loss=-1.7720, critic_loss=0.0771, avg_q=1.595
# 🧬 Evolution G13: 21 mutations, improvement: 0.0080
# [MADDPG-EVO] Epoch 190/1000: reward=51.074, regions=30, noise=0.205
#   📊 Metrics: actor_loss=-1.8159, critic_loss=0.0725, avg_q=1.657
# 🧬 Evolution G14: 22 mutations, improvement: 0.0086
# [MADDPG-EVO] Epoch 200/1000: reward=52.773, regions=31, noise=0.201
#   📊 Metrics: actor_loss=-1.6854, critic_loss=0.0865, avg_q=1.553
# [MADDPG-EVO] Epoch 210/1000: reward=55.225, regions=33, noise=0.197
#   📊 Metrics: actor_loss=-1.7803, critic_loss=0.1124, avg_q=1.582
# 🧬 Evolution G15: 24 mutations, improvement: 0.0075
# [MADDPG-EVO] Epoch 220/1000: reward=56.707, regions=34, noise=0.193
#   📊 Metrics: actor_loss=-1.7682, critic_loss=0.0865, avg_q=1.687
# 🧬 Evolution G16: 25 mutations, improvement: 0.0072
# [MADDPG-EVO] Epoch 230/1000: reward=58.521, regions=35, noise=0.189
#   📊 Metrics: actor_loss=-1.7004, critic_loss=0.1312, avg_q=1.618
# [MADDPG-EVO] Epoch 240/1000: reward=60.164, regions=37, noise=0.186
#   📊 Metrics: actor_loss=-1.7363, critic_loss=0.0702, avg_q=1.585
# 🧬 Evolution G17: 26 mutations, improvement: 0.0073
# [MADDPG-EVO] Epoch 250/1000: reward=61.702, regions=38, noise=0.182
#   📊 Metrics: actor_loss=-1.6931, critic_loss=0.0709, avg_q=1.534
# 🧬 Evolution G18: 28 mutations, improvement: 0.0069
# [MADDPG-EVO] Epoch 260/1000: reward=63.789, regions=39, noise=0.178
#   📊 Metrics: actor_loss=-1.6609, critic_loss=0.1046, avg_q=1.514
# [MADDPG-EVO] Epoch 270/1000: reward=65.576, regions=41, noise=0.175
#   📊 Metrics: actor_loss=-1.6277, critic_loss=0.1134, avg_q=1.377
# 🧬 Evolution G19: 29 mutations, improvement: 0.0082
# [MADDPG-EVO] Epoch 280/1000: reward=67.749, regions=42, noise=0.171
#   📊 Metrics: actor_loss=-1.7037, critic_loss=0.0909, avg_q=1.545
# 🧬 Evolution G20: 31 mutations, improvement: 0.0075
# [MADDPG-EVO] Epoch 290/1000: reward=68.266, regions=44, noise=0.168
#   📊 Metrics: actor_loss=-1.7133, critic_loss=0.1358, avg_q=1.658
# [MADDPG-EVO] Epoch 300/1000: reward=70.751, regions=45, noise=0.165
#   📊 Metrics: actor_loss=-1.7352, critic_loss=0.1220, avg_q=1.603
# 🧬 Evolution G21: 32 mutations, improvement: 0.0069
# [MADDPG-EVO] Epoch 310/1000: reward=72.913, regions=46, noise=0.161
#   📊 Metrics: actor_loss=-1.6104, critic_loss=0.1131, avg_q=1.491
# 🧬 Evolution G22: 33 mutations, improvement: 0.0058
# [MADDPG-EVO] Epoch 320/1000: reward=74.005, regions=48, noise=0.158
#   📊 Metrics: actor_loss=-1.6607, critic_loss=0.1400, avg_q=1.530
# [MADDPG-EVO] Epoch 330/1000: reward=75.673, regions=49, noise=0.155
#   📊 Metrics: actor_loss=-1.7329, critic_loss=0.1648, avg_q=1.610
# 🧬 Evolution G23: 35 mutations, improvement: 0.0067
# [MADDPG-EVO] Epoch 340/1000: reward=78.014, regions=50, noise=0.152
#   📊 Metrics: actor_loss=-1.6612, critic_loss=0.0935, avg_q=1.481
# 🧬 Evolution G24: 36 mutations, improvement: 0.0079
# [MADDPG-EVO] Epoch 350/1000: reward=78.622, regions=52, noise=0.149
#   📊 Metrics: actor_loss=-1.7200, critic_loss=0.1268, avg_q=1.563
# [MADDPG-EVO] Epoch 360/1000: reward=80.196, regions=53, noise=0.146
#   📊 Metrics: actor_loss=-1.6311, critic_loss=0.1740, avg_q=1.419
# 🧬 Evolution G25: 38 mutations, improvement: 0.0058
# [MADDPG-EVO] Epoch 370/1000: reward=81.361, regions=54, noise=0.143
#   📊 Metrics: actor_loss=-1.5981, critic_loss=0.1573, avg_q=1.445
# 🧬 Evolution G26: 39 mutations, improvement: 0.0076
# [MADDPG-EVO] Epoch 380/1000: reward=84.145, regions=56, noise=0.140
#   📊 Metrics: actor_loss=-1.6520, critic_loss=0.1690, avg_q=1.527
# [MADDPG-EVO] Epoch 390/1000: reward=84.318, regions=57, noise=0.137
#   📊 Metrics: actor_loss=-1.6199, critic_loss=0.1515, avg_q=1.434
# 🧬 Evolution G27: 40 mutations, improvement: 0.0073
# [MADDPG-EVO] Epoch 400/1000: reward=86.107, regions=58, noise=0.135
#   📊 Metrics: actor_loss=-1.6994, critic_loss=0.1570, avg_q=1.510
# 🧬 Evolution G28: 42 mutations, improvement: 0.0073
# [MADDPG-EVO] Epoch 410/1000: reward=87.341, regions=60, noise=0.132
#   📊 Metrics: actor_loss=-1.6430, critic_loss=0.1481, avg_q=1.445
# [MADDPG-EVO] Epoch 420/1000: reward=89.598, regions=61, noise=0.129
#   📊 Metrics: actor_loss=-1.6713, critic_loss=0.1772, avg_q=1.371
# 🧬 Evolution G29: 43 mutations, improvement: 0.0050
# [MADDPG-EVO] Epoch 430/1000: reward=91.598, regions=62, noise=0.127
#   📊 Metrics: actor_loss=-1.6599, critic_loss=0.1635, avg_q=1.413
# 🧬 Evolution G30: 45 mutations, improvement: 0.0060
# [MADDPG-EVO] Epoch 440/1000: reward=92.507, regions=64, noise=0.124
#   📊 Metrics: actor_loss=-1.6189, critic_loss=0.1924, avg_q=1.402
# [MADDPG-EVO] Epoch 450/1000: reward=94.211, regions=65, noise=0.122
#   📊 Metrics: actor_loss=-1.5735, critic_loss=0.2396, avg_q=1.343
# 🧬 Evolution G31: 46 mutations, improvement: 0.0056
# [MADDPG-EVO] Epoch 460/1000: reward=94.155, regions=66, noise=0.119
#   📊 Metrics: actor_loss=-1.6292, critic_loss=0.2452, avg_q=1.376
# 🧬 Evolution G32: 47 mutations, improvement: 0.0058
# [MADDPG-EVO] Epoch 470/1000: reward=95.768, regions=68, noise=0.117
#   📊 Metrics: actor_loss=-1.6045, critic_loss=0.2404, avg_q=1.364
# [MADDPG-EVO] Epoch 480/1000: reward=96.987, regions=69, noise=0.115
#   📊 Metrics: actor_loss=-1.6074, critic_loss=0.2572, avg_q=1.454
# 🧬 Evolution G33: 49 mutations, improvement: 0.0067
# [MADDPG-EVO] Epoch 490/1000: reward=99.494, regions=71, noise=0.112
#   📊 Metrics: actor_loss=-1.6660, critic_loss=0.2891, avg_q=1.362
# 🧬 Evolution G34: 50 mutations, improvement: 0.0051
# [MADDPG-EVO] Epoch 500/1000: reward=100.690, regions=72, noise=0.110
#   📊 Metrics: actor_loss=-1.7095, critic_loss=0.2704, avg_q=1.484
# [MADDPG-EVO] Epoch 510/1000: reward=100.470, regions=73, noise=0.108
#   📊 Metrics: actor_loss=-1.6804, critic_loss=0.3664, avg_q=1.487
# 🧬 Evolution G35: 52 mutations, improvement: 0.0052
# [MADDPG-EVO] Epoch 520/1000: reward=102.415, regions=75, noise=0.106
#   📊 Metrics: actor_loss=-1.6058, critic_loss=0.2818, avg_q=1.451
# 🧬 Evolution G36: 53 mutations, improvement: 0.0050
# [MADDPG-EVO] Epoch 530/1000: reward=102.426, regions=76, noise=0.104
#   📊 Metrics: actor_loss=-1.6505, critic_loss=0.2663, avg_q=1.376
# [MADDPG-EVO] Epoch 540/1000: reward=105.002, regions=77, noise=0.102
#   📊 Metrics: actor_loss=-1.6931, critic_loss=0.3036, avg_q=1.481
# 🧬 Evolution G37: 54 mutations, improvement: 0.0037
# [MADDPG-EVO] Epoch 550/1000: reward=104.765, regions=79, noise=0.100
#   📊 Metrics: actor_loss=-1.6040, critic_loss=0.3301, avg_q=1.324
# 🧬 Evolution G38: 56 mutations, improvement: 0.0048
# [MADDPG-EVO] Epoch 560/1000: reward=107.122, regions=80, noise=0.098
#   📊 Metrics: actor_loss=-1.6903, critic_loss=0.3151, avg_q=1.428
# [MADDPG-EVO] Epoch 570/1000: reward=108.287, regions=81, noise=0.096
#   📊 Metrics: actor_loss=-1.5678, critic_loss=0.3680, avg_q=1.308
# 🧬 Evolution G39: 57 mutations, improvement: 0.0058
# [MADDPG-EVO] Epoch 580/1000: reward=108.997, regions=83, noise=0.094
#   📊 Metrics: actor_loss=-1.5749, critic_loss=0.3714, avg_q=1.311
# 🧬 Evolution G40: 59 mutations, improvement: 0.0055
# [MADDPG-EVO] Epoch 590/1000: reward=109.428, regions=84, noise=0.092
#   📊 Metrics: actor_loss=-1.6655, critic_loss=0.3960, avg_q=1.439
# [MADDPG-EVO] Epoch 600/1000: reward=110.404, regions=85, noise=0.090
#   📊 Metrics: actor_loss=-1.6156, critic_loss=0.4201, avg_q=1.380
# 🧬 Evolution G41: 61 mutations, improvement: 0.0048
# [MADDPG-EVO] Epoch 610/1000: reward=109.714, regions=86, noise=0.088
#   📊 Metrics: actor_loss=-1.6423, critic_loss=0.4099, avg_q=1.457
# 🧬 Evolution G42: 61 mutations, improvement: 0.0051
# [MADDPG-EVO] Epoch 620/1000: reward=109.265, regions=86, noise=0.087
#   📊 Metrics: actor_loss=-1.6748, critic_loss=0.4590, avg_q=1.449
# [MADDPG-EVO] Epoch 630/1000: reward=108.509, regions=86, noise=0.085
#   📊 Metrics: actor_loss=-1.5463, critic_loss=0.4390, avg_q=1.294
# 🧬 Evolution G43: 61 mutations, improvement: 0.0047
# [MADDPG-EVO] Epoch 640/1000: reward=106.780, regions=86, noise=0.083
#   📊 Metrics: actor_loss=-1.6390, critic_loss=0.4978, avg_q=1.422
# 🧬 Evolution G44: 61 mutations, improvement: 0.0064
# [MADDPG-EVO] Epoch 650/1000: reward=104.041, regions=86, noise=0.082
#   📊 Metrics: actor_loss=-1.7210, critic_loss=0.4111, avg_q=1.462
# [MADDPG-EVO] Epoch 660/1000: reward=102.295, regions=86, noise=0.080
#   📊 Metrics: actor_loss=-1.5428, critic_loss=0.5254, avg_q=1.226
# 🧬 Evolution G45: 61 mutations, improvement: 0.0055
# [MADDPG-EVO] Epoch 670/1000: reward=100.142, regions=86, noise=0.078
#   📊 Metrics: actor_loss=-1.5958, critic_loss=0.4426, avg_q=1.389
# 🧬 Evolution G46: 61 mutations, improvement: 0.0049
# [MADDPG-EVO] Epoch 680/1000: reward=99.241, regions=86, noise=0.077
#   📊 Metrics: actor_loss=-1.6052, critic_loss=0.6487, avg_q=1.390
# [MADDPG-EVO] Epoch 690/1000: reward=96.221, regions=86, noise=0.075
#   📊 Metrics: actor_loss=-1.6427, critic_loss=0.4510, avg_q=1.329
# 🧬 Evolution G47: 61 mutations, improvement: 0.0041
# [MADDPG-EVO] Epoch 700/1000: reward=95.051, regions=86, noise=0.074
#   📊 Metrics: actor_loss=-1.7226, critic_loss=0.5427, avg_q=1.411
# 🧬 Evolution G48: 61 mutations, improvement: 0.0042
# [MADDPG-EVO] Epoch 710/1000: reward=93.968, regions=86, noise=0.072
#   📊 Metrics: actor_loss=-1.6043, critic_loss=0.5492, avg_q=1.331
# [MADDPG-EVO] Epoch 720/1000: reward=93.332, regions=86, noise=0.071
#   📊 Metrics: actor_loss=-1.6192, critic_loss=0.4100, avg_q=1.317
# 🧬 Evolution G49: 61 mutations, improvement: 0.0057
# [MADDPG-EVO] Epoch 730/1000: reward=90.528, regions=86, noise=0.070
#   📊 Metrics: actor_loss=-1.6519, critic_loss=0.5808, avg_q=1.403
# 🧬 Evolution G50: 61 mutations, improvement: 0.0049
# [MADDPG-EVO] Epoch 740/1000: reward=88.434, regions=86, noise=0.068
#   📊 Metrics: actor_loss=-1.5720, critic_loss=0.6232, avg_q=1.380
# [MADDPG-EVO] Epoch 750/1000: reward=87.703, regions=86, noise=0.067
#   📊 Metrics: actor_loss=-1.5963, critic_loss=0.5480, avg_q=1.351
# 🧬 Evolution G51: 61 mutations, improvement: 0.0047
# [MADDPG-EVO] Epoch 760/1000: reward=86.515, regions=86, noise=0.066
#   📊 Metrics: actor_loss=-1.6269, critic_loss=0.6014, avg_q=1.321
# 🧬 Evolution G52: 61 mutations, improvement: 0.0055
# [MADDPG-EVO] Epoch 770/1000: reward=85.275, regions=86, noise=0.064
#   📊 Metrics: actor_loss=-1.5201, critic_loss=0.6095, avg_q=1.266
# [MADDPG-EVO] Epoch 780/1000: reward=83.749, regions=86, noise=0.063
#   📊 Metrics: actor_loss=-1.5401, critic_loss=0.5044, avg_q=1.305
# 🧬 Evolution G53: 61 mutations, improvement: 0.0051
# [MADDPG-EVO] Epoch 790/1000: reward=82.174, regions=86, noise=0.062
#   📊 Metrics: actor_loss=-1.6312, critic_loss=0.6293, avg_q=1.286
# 🧬 Evolution G54: 61 mutations, improvement: 0.0046
# [MADDPG-EVO] Epoch 800/1000: reward=80.089, regions=86, noise=0.060
#   📊 Metrics: actor_loss=-1.5480, critic_loss=0.6438, avg_q=1.233
# [MADDPG-EVO] Epoch 810/1000: reward=79.317, regions=86, noise=0.059
#   📊 Metrics: actor_loss=-1.5705, critic_loss=0.7244, avg_q=1.346
# 🧬 Evolution G55: 61 mutations, improvement: 0.0045
# [MADDPG-EVO] Epoch 820/1000: reward=78.844, regions=86, noise=0.058
#   📊 Metrics: actor_loss=-1.6151, critic_loss=0.5790, avg_q=1.368
# 🧬 Evolution G56: 61 mutations, improvement: 0.0036
# [MADDPG-EVO] Epoch 830/1000: reward=77.894, regions=86, noise=0.057
#   📊 Metrics: actor_loss=-1.5533, critic_loss=0.5863, avg_q=1.348
# [MADDPG-EVO] Epoch 840/1000: reward=75.880, regions=86, noise=0.056
#   📊 Metrics: actor_loss=-1.4975, critic_loss=0.6124, avg_q=1.335
# 🧬 Evolution G57: 61 mutations, improvement: 0.0046
# [MADDPG-EVO] Epoch 850/1000: reward=75.191, regions=86, noise=0.055
#   📊 Metrics: actor_loss=-1.5586, critic_loss=0.6932, avg_q=1.329
# 🧬 Evolution G58: 61 mutations, improvement: 0.0041
# [MADDPG-EVO] Epoch 860/1000: reward=74.514, regions=86, noise=0.054
#   📊 Metrics: actor_loss=-1.5336, critic_loss=0.7676, avg_q=1.220
# [MADDPG-EVO] Epoch 870/1000: reward=73.345, regions=86, noise=0.053
#   📊 Metrics: actor_loss=-1.6289, critic_loss=0.5216, avg_q=1.301
# 🧬 Evolution G59: 61 mutations, improvement: 0.0033
# [MADDPG-EVO] Epoch 880/1000: reward=73.516, regions=86, noise=0.052
#   📊 Metrics: actor_loss=-1.5707, critic_loss=0.7433, avg_q=1.337
# 🧬 Evolution G60: 61 mutations, improvement: 0.0027
# [MADDPG-EVO] Epoch 890/1000: reward=71.911, regions=86, noise=0.051
#   📊 Metrics: actor_loss=-1.5044, critic_loss=0.8006, avg_q=1.222
# [MADDPG-EVO] Epoch 900/1000: reward=71.282, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-1.5618, critic_loss=0.8738, avg_q=1.289
# 🧬 Evolution G61: 61 mutations, improvement: 0.0034
# [MADDPG-EVO] Epoch 910/1000: reward=70.679, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-1.4540, critic_loss=0.8279, avg_q=1.248
# 🧬 Evolution G62: 61 mutations, improvement: 0.0035
# [MADDPG-EVO] Epoch 920/1000: reward=70.592, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-1.4882, critic_loss=0.9373, avg_q=1.170
# [MADDPG-EVO] Epoch 930/1000: reward=70.396, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-1.5675, critic_loss=0.6738, avg_q=1.202
# 🧬 Evolution G63: 61 mutations, improvement: 0.0035
# [MADDPG-EVO] Epoch 940/1000: reward=68.867, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-1.5180, critic_loss=0.7888, avg_q=1.212
# 🧬 Evolution G64: 61 mutations, improvement: 0.0034
# [MADDPG-EVO] Epoch 950/1000: reward=67.722, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-1.5756, critic_loss=0.8716, avg_q=1.246
# [MADDPG-EVO] Epoch 960/1000: reward=68.104, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-1.4774, critic_loss=0.7549, avg_q=1.220
# 🧬 Evolution G65: 61 mutations, improvement: 0.0033
# [MADDPG-EVO] Epoch 970/1000: reward=68.245, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-1.6125, critic_loss=0.7199, avg_q=1.405
# 🧬 Evolution G66: 61 mutations, improvement: 0.0030
# [MADDPG-EVO] Epoch 980/1000: reward=68.601, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-1.4254, critic_loss=0.8499, avg_q=1.214
# [MADDPG-EVO] Epoch 990/1000: reward=67.140, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-1.4932, critic_loss=0.9781, avg_q=1.205
# 🧬 Evolution G67: 61 mutations, improvement: 0.0037
# [MADDPG-EVO] Epoch 1000/1000: reward=68.479, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-1.5299, critic_loss=0.9112, avg_q=1.353
# 🧪 TESTING PHASE (200 epochs)
# MADDPG-EVO Testing:   0%|          | 0/200 [00:00<?, ?it/s]
# ✅ MADDPG-EVO - TRAINING COMPLETED:
#   📊 Final reward: 67.8096
#   📈 Maximum reward: 114.0592
#   📊 Overall improvement: 53.3424
#   🧪 Test reward: 67.9187
#   🧪 Max in test: 71.4106
#   📊 Stability: 1.002
#   🤖 Trained agents: 86
#   💾 Total experience: 920415
# 🔄 Preparing MADDPG-EVO-DGM...
# 🚀 TRAINING MADDPG-EVO-DGM
# 📊 Training: 1000 epochs | Testing: 200 epochs
# ============================================================
# 🎓 TRAINING PHASE
# MADDPG-EVO-DGM Training:   0%|          | 0/1000 [00:00<?, ?it/s]
# 🧬 Evolution G1: 4 mutations, improvement: 0.0114
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 10/1000: reward=10.969, regions=6, noise=0.294
#   📊 Metrics: actor_loss=-1.6066, critic_loss=0.6121, avg_q=2.091
# 🧬 Evolution G2: 5 mutations, improvement: 0.0130
# [MADDPG-EVO-DGM] Epoch 20/1000: reward=13.239, regions=7, noise=0.288
#   📊 Metrics: actor_loss=-2.0587, critic_loss=0.2000, avg_q=2.116
# [MADDPG-EVO-DGM] Epoch 30/1000: reward=15.746, regions=8, noise=0.283
#   📊 Metrics: actor_loss=-2.0117, critic_loss=0.1113, avg_q=2.010
# 🧬 Evolution G3: 7 mutations, improvement: 0.0088
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 40/1000: reward=19.503, regions=10, noise=0.277
#   📊 Metrics: actor_loss=-2.1115, critic_loss=0.1155, avg_q=2.107
# 🧬 Evolution G4: 8 mutations, improvement: 0.0095
# [MADDPG-EVO-DGM] Epoch 50/1000: reward=21.419, regions=11, noise=0.271
#   📊 Metrics: actor_loss=-2.1686, critic_loss=0.1270, avg_q=2.067
# [MADDPG-EVO-DGM] Epoch 60/1000: reward=23.433, regions=12, noise=0.266
#   📊 Metrics: actor_loss=-2.2206, critic_loss=0.1012, avg_q=2.134
# 🧬 Evolution G5: 10 mutations, improvement: 0.0127
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 70/1000: reward=26.381, regions=14, noise=0.261
#   📊 Metrics: actor_loss=-2.1942, critic_loss=0.0670, avg_q=2.118
# 🧬 Evolution G6: 11 mutations, improvement: 0.0082
# [MADDPG-EVO-DGM] Epoch 80/1000: reward=28.573, regions=15, noise=0.256
#   📊 Metrics: actor_loss=-2.2549, critic_loss=0.1021, avg_q=2.154
# [MADDPG-EVO-DGM] Epoch 90/1000: reward=30.880, regions=17, noise=0.251
# ...
# 🧬 Evolution G15: 24 mutations, improvement: 0.0096
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 220/1000: reward=57.109, regions=34, noise=0.193
#   📊 Metrics: actor_loss=-2.4226, critic_loss=0.0986, avg_q=2.229
# 🧬 Evolution G16: 25 mutations, improvement: 0.0050
# [MADDPG-EVO-DGM] Epoch 230/1000: reward=59.677, regions=35, noise=0.189
#   📊 Metrics: actor_loss=-2.5081, critic_loss=0.1157, avg_q=2.388
# [MADDPG-EVO-DGM] Epoch 240/1000: reward=61.982, regions=37, noise=0.186
#   📊 Metrics: actor_loss=-2.4800, critic_loss=0.0863, avg_q=2.326
# 🧬 Evolution G17: 26 mutations, improvement: 0.0082
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 250/1000: reward=62.801, regions=38, noise=0.182
#   📊 Metrics: actor_loss=-2.4468, critic_loss=0.0962, avg_q=2.262
# 🧬 Evolution G18: 28 mutations, improvement: 0.0062
# [MADDPG-EVO-DGM] Epoch 260/1000: reward=65.439, regions=39, noise=0.178
#   📊 Metrics: actor_loss=-2.4833, critic_loss=0.0949, avg_q=2.306
# [MADDPG-EVO-DGM] Epoch 270/1000: reward=67.058, regions=41, noise=0.175
#   📊 Metrics: actor_loss=-2.4835, critic_loss=0.0932, avg_q=2.330
# 🧬 Evolution G19: 29 mutations, improvement: 0.0081
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 280/1000: reward=69.208, regions=42, noise=0.171
#   📊 Metrics: actor_loss=-2.5495, critic_loss=0.1148, avg_q=2.378
# 🧬 Evolution G20: 31 mutations, improvement: 0.0080
# [MADDPG-EVO-DGM] Epoch 290/1000: reward=70.990, regions=44, noise=0.168
#   📊 Metrics: actor_loss=-2.5236, critic_loss=0.0955, avg_q=2.356
# [MADDPG-EVO-DGM] Epoch 300/1000: reward=74.204, regions=45, noise=0.165
#   📊 Metrics: actor_loss=-2.5943, critic_loss=0.1220, avg_q=2.419
# 🧬 Evolution G21: 32 mutations, improvement: 0.0079
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 310/1000: reward=75.548, regions=46, noise=0.161
#   📊 Metrics: actor_loss=-2.6375, critic_loss=0.1153, avg_q=2.444
# 🧬 Evolution G22: 33 mutations, improvement: 0.0071
# [MADDPG-EVO-DGM] Epoch 320/1000: reward=77.149, regions=48, noise=0.158
#   📊 Metrics: actor_loss=-2.6316, critic_loss=0.1177, avg_q=2.462
# [MADDPG-EVO-DGM] Epoch 330/1000: reward=80.166, regions=49, noise=0.155
#   📊 Metrics: actor_loss=-2.6367, critic_loss=0.1102, avg_q=2.442
# 🧬 Evolution G23: 35 mutations, improvement: 0.0072
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 340/1000: reward=81.030, regions=50, noise=0.152
#   📊 Metrics: actor_loss=-2.5781, critic_loss=0.1325, avg_q=2.365
# 🧬 Evolution G24: 36 mutations, improvement: 0.0071
# [MADDPG-EVO-DGM] Epoch 350/1000: reward=83.582, regions=52, noise=0.149
#   📊 Metrics: actor_loss=-2.6201, critic_loss=0.1401, avg_q=2.456
# [MADDPG-EVO-DGM] Epoch 360/1000: reward=86.456, regions=53, noise=0.146
#   📊 Metrics: actor_loss=-2.6663, critic_loss=0.1448, avg_q=2.470
# 🧬 Evolution G25: 38 mutations, improvement: 0.0083
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 370/1000: reward=88.622, regions=54, noise=0.143
#   📊 Metrics: actor_loss=-2.6754, critic_loss=0.1389, avg_q=2.476
# 🧬 Evolution G26: 39 mutations, improvement: 0.0047
# [MADDPG-EVO-DGM] Epoch 380/1000: reward=90.934, regions=56, noise=0.140
#   📊 Metrics: actor_loss=-2.7013, critic_loss=0.1503, avg_q=2.516
# [MADDPG-EVO-DGM] Epoch 390/1000: reward=91.984, regions=57, noise=0.137
#   📊 Metrics: actor_loss=-2.7075, critic_loss=0.1819, avg_q=2.466
# 🧬 Evolution G27: 40 mutations, improvement: 0.0052
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 400/1000: reward=94.427, regions=58, noise=0.135
#   📊 Metrics: actor_loss=-2.7322, critic_loss=0.1811, avg_q=2.500
# 🧬 Evolution G28: 42 mutations, improvement: 0.0052
# [MADDPG-EVO-DGM] Epoch 410/1000: reward=96.345, regions=60, noise=0.132
#   📊 Metrics: actor_loss=-2.7246, critic_loss=0.1615, avg_q=2.497
# [MADDPG-EVO-DGM] Epoch 420/1000: reward=98.283, regions=61, noise=0.129
#   📊 Metrics: actor_loss=-2.8045, critic_loss=0.1898, avg_q=2.568
# 🧬 Evolution G29: 43 mutations, improvement: 0.0062
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 430/1000: reward=100.650, regions=62, noise=0.127
#   📊 Metrics: actor_loss=-2.8259, critic_loss=0.1953, avg_q=2.588
# 🧬 Evolution G30: 45 mutations, improvement: 0.0058
# [MADDPG-EVO-DGM] Epoch 440/1000: reward=102.609, regions=64, noise=0.124
#   📊 Metrics: actor_loss=-2.8297, critic_loss=0.1812, avg_q=2.594
# [MADDPG-EVO-DGM] Epoch 450/1000: reward=104.923, regions=65, noise=0.122
#   📊 Metrics: actor_loss=-2.8274, critic_loss=0.2130, avg_q=2.583
# 🧬 Evolution G31: 46 mutations, improvement: 0.0066
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 460/1000: reward=106.365, regions=66, noise=0.119
#   📊 Metrics: actor_loss=-2.8411, critic_loss=0.2191, avg_q=2.586
# 🧬 Evolution G32: 47 mutations, improvement: 0.0054
# [MADDPG-EVO-DGM] Epoch 470/1000: reward=108.463, regions=68, noise=0.117
#   📊 Metrics: actor_loss=-2.8824, critic_loss=0.2447, avg_q=2.635
# [MADDPG-EVO-DGM] Epoch 480/1000: reward=110.898, regions=69, noise=0.115
#   📊 Metrics: actor_loss=-2.9364, critic_loss=0.2279, avg_q=2.677
# 🧬 Evolution G33: 49 mutations, improvement: 0.0059
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 490/1000: reward=114.093, regions=71, noise=0.112
#   📊 Metrics: actor_loss=-2.9662, critic_loss=0.2866, avg_q=2.695
# 🧬 Evolution G34: 50 mutations, improvement: 0.0067
# [MADDPG-EVO-DGM] Epoch 500/1000: reward=115.577, regions=72, noise=0.110
#   📊 Metrics: actor_loss=-2.9731, critic_loss=0.2423, avg_q=2.707
# [MADDPG-EVO-DGM] Epoch 510/1000: reward=117.401, regions=73, noise=0.108
#   📊 Metrics: actor_loss=-2.9740, critic_loss=0.2789, avg_q=2.700
# 🧬 Evolution G35: 52 mutations, improvement: 0.0050
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 520/1000: reward=119.276, regions=75, noise=0.106
#   📊 Metrics: actor_loss=-2.9956, critic_loss=0.2655, avg_q=2.693
# 🧬 Evolution G36: 53 mutations, improvement: 0.0067
# [MADDPG-EVO-DGM] Epoch 530/1000: reward=121.490, regions=76, noise=0.104
#   📊 Metrics: actor_loss=-2.9989, critic_loss=0.3229, avg_q=2.709
# [MADDPG-EVO-DGM] Epoch 540/1000: reward=123.238, regions=77, noise=0.102
#   📊 Metrics: actor_loss=-3.0203, critic_loss=0.2852, avg_q=2.735
# 🧬 Evolution G37: 54 mutations, improvement: 0.0065
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 550/1000: reward=125.818, regions=79, noise=0.100
#   📊 Metrics: actor_loss=-3.0527, critic_loss=0.3306, avg_q=2.762
# 🧬 Evolution G38: 56 mutations, improvement: 0.0060
# [MADDPG-EVO-DGM] Epoch 560/1000: reward=126.387, regions=80, noise=0.098
#   📊 Metrics: actor_loss=-3.0971, critic_loss=0.3813, avg_q=2.794
# [MADDPG-EVO-DGM] Epoch 570/1000: reward=128.948, regions=81, noise=0.096
#   📊 Metrics: actor_loss=-3.1145, critic_loss=0.3580, avg_q=2.836
# 🧬 Evolution G39: 57 mutations, improvement: 0.0055
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 580/1000: reward=130.757, regions=83, noise=0.094
#   📊 Metrics: actor_loss=-3.1559, critic_loss=0.4470, avg_q=2.839
# 🧬 Evolution G40: 59 mutations, improvement: 0.0060
# [MADDPG-EVO-DGM] Epoch 590/1000: reward=134.280, regions=84, noise=0.092
#   📊 Metrics: actor_loss=-3.1511, critic_loss=0.4574, avg_q=2.838
# [MADDPG-EVO-DGM] Epoch 600/1000: reward=136.093, regions=85, noise=0.090
#   📊 Metrics: actor_loss=-3.1738, critic_loss=0.4641, avg_q=2.853
# 🧬 Evolution G41: 61 mutations, improvement: 0.0069
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 610/1000: reward=138.066, regions=86, noise=0.088
#   📊 Metrics: actor_loss=-3.1846, critic_loss=0.4624, avg_q=2.881
# 🧬 Evolution G42: 61 mutations, improvement: 0.0049
# [MADDPG-EVO-DGM] Epoch 620/1000: reward=135.488, regions=86, noise=0.087
#   📊 Metrics: actor_loss=-3.2212, critic_loss=0.5646, avg_q=2.899
# [MADDPG-EVO-DGM] Epoch 630/1000: reward=134.463, regions=86, noise=0.085
#   📊 Metrics: actor_loss=-3.2267, critic_loss=0.6050, avg_q=2.916
# 🧬 Evolution G43: 61 mutations, improvement: 0.0055
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 640/1000: reward=134.242, regions=86, noise=0.083
#   📊 Metrics: actor_loss=-3.2551, critic_loss=0.4961, avg_q=2.918
# 🧬 Evolution G44: 61 mutations, improvement: 0.0046
# [MADDPG-EVO-DGM] Epoch 650/1000: reward=133.144, regions=86, noise=0.082
#   📊 Metrics: actor_loss=-3.2895, critic_loss=0.6354, avg_q=2.941
# [MADDPG-EVO-DGM] Epoch 660/1000: reward=132.103, regions=86, noise=0.080
#   📊 Metrics: actor_loss=-3.3356, critic_loss=0.4867, avg_q=2.978
# 🧬 Evolution G45: 61 mutations, improvement: 0.0045
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 670/1000: reward=132.076, regions=86, noise=0.078
#   📊 Metrics: actor_loss=-3.3288, critic_loss=0.7299, avg_q=2.972
# 🧬 Evolution G46: 61 mutations, improvement: 0.0047
# [MADDPG-EVO-DGM] Epoch 680/1000: reward=130.388, regions=86, noise=0.077
#   📊 Metrics: actor_loss=-3.3492, critic_loss=0.6575, avg_q=3.012
# [MADDPG-EVO-DGM] Epoch 690/1000: reward=131.397, regions=86, noise=0.075
#   📊 Metrics: actor_loss=-3.3853, critic_loss=0.6949, avg_q=3.020
# 🧬 Evolution G47: 61 mutations, improvement: 0.0051
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 700/1000: reward=131.340, regions=86, noise=0.074
#   📊 Metrics: actor_loss=-3.4027, critic_loss=0.6973, avg_q=3.047
# 🧬 Evolution G48: 61 mutations, improvement: 0.0038
# [MADDPG-EVO-DGM] Epoch 710/1000: reward=128.958, regions=86, noise=0.072
#   📊 Metrics: actor_loss=-3.4469, critic_loss=0.7355, avg_q=3.063
# [MADDPG-EVO-DGM] Epoch 720/1000: reward=129.158, regions=86, noise=0.071
#   📊 Metrics: actor_loss=-3.4449, critic_loss=0.8603, avg_q=3.094
# 🧬 Evolution G49: 61 mutations, improvement: 0.0053
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 730/1000: reward=128.841, regions=86, noise=0.070
#   📊 Metrics: actor_loss=-3.4476, critic_loss=0.8143, avg_q=3.065
# 🧬 Evolution G50: 61 mutations, improvement: 0.0041
# [MADDPG-EVO-DGM] Epoch 740/1000: reward=127.847, regions=86, noise=0.068
#   📊 Metrics: actor_loss=-3.4913, critic_loss=0.8251, avg_q=3.103
# [MADDPG-EVO-DGM] Epoch 750/1000: reward=126.229, regions=86, noise=0.067
#   📊 Metrics: actor_loss=-3.4920, critic_loss=0.9843, avg_q=3.130
# 🧬 Evolution G51: 61 mutations, improvement: 0.0041
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 760/1000: reward=127.168, regions=86, noise=0.066
#   📊 Metrics: actor_loss=-3.5479, critic_loss=1.0585, avg_q=3.159
# 🧬 Evolution G52: 61 mutations, improvement: 0.0041
# [MADDPG-EVO-DGM] Epoch 770/1000: reward=126.525, regions=86, noise=0.064
#   📊 Metrics: actor_loss=-3.5522, critic_loss=1.1310, avg_q=3.154
# [MADDPG-EVO-DGM] Epoch 780/1000: reward=125.555, regions=86, noise=0.063
#   📊 Metrics: actor_loss=-3.5733, critic_loss=1.0201, avg_q=3.158
# 🧬 Evolution G53: 61 mutations, improvement: 0.0047
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 790/1000: reward=124.628, regions=86, noise=0.062
#   📊 Metrics: actor_loss=-3.5901, critic_loss=1.2360, avg_q=3.182
# 🧬 Evolution G54: 61 mutations, improvement: 0.0036
# [MADDPG-EVO-DGM] Epoch 800/1000: reward=124.724, regions=86, noise=0.060
#   📊 Metrics: actor_loss=-3.5792, critic_loss=1.1667, avg_q=3.179
# [MADDPG-EVO-DGM] Epoch 810/1000: reward=123.460, regions=86, noise=0.059
#   📊 Metrics: actor_loss=-3.6312, critic_loss=1.2539, avg_q=3.198
# 🧬 Evolution G55: 61 mutations, improvement: 0.0044
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 820/1000: reward=122.912, regions=86, noise=0.058
#   📊 Metrics: actor_loss=-3.6341, critic_loss=1.3879, avg_q=3.230
# 🧬 Evolution G56: 61 mutations, improvement: 0.0044
# [MADDPG-EVO-DGM] Epoch 830/1000: reward=123.210, regions=86, noise=0.057
#   📊 Metrics: actor_loss=-3.6577, critic_loss=1.3623, avg_q=3.251
# [MADDPG-EVO-DGM] Epoch 840/1000: reward=123.077, regions=86, noise=0.056
#   📊 Metrics: actor_loss=-3.6765, critic_loss=1.2711, avg_q=3.269
# 🧬 Evolution G57: 61 mutations, improvement: 0.0044
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 850/1000: reward=122.139, regions=86, noise=0.055
#   📊 Metrics: actor_loss=-3.6745, critic_loss=1.3861, avg_q=3.256
# 🧬 Evolution G58: 61 mutations, improvement: 0.0035
# [MADDPG-EVO-DGM] Epoch 860/1000: reward=120.582, regions=86, noise=0.054
#   📊 Metrics: actor_loss=-3.7339, critic_loss=1.6928, avg_q=3.302
# [MADDPG-EVO-DGM] Epoch 870/1000: reward=120.961, regions=86, noise=0.053
#   📊 Metrics: actor_loss=-3.7076, critic_loss=1.6090, avg_q=3.310
# 🧬 Evolution G59: 61 mutations, improvement: 0.0037
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 880/1000: reward=121.200, regions=86, noise=0.052
#   📊 Metrics: actor_loss=-3.6959, critic_loss=1.6032, avg_q=3.311
# 🧬 Evolution G60: 61 mutations, improvement: 0.0034
# [MADDPG-EVO-DGM] Epoch 890/1000: reward=122.315, regions=86, noise=0.051
#   📊 Metrics: actor_loss=-3.7721, critic_loss=1.7147, avg_q=3.359
# [MADDPG-EVO-DGM] Epoch 900/1000: reward=121.468, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-3.7757, critic_loss=1.8505, avg_q=3.382
# 🧬 Evolution G61: 61 mutations, improvement: 0.0041
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 910/1000: reward=121.239, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-3.7724, critic_loss=1.8308, avg_q=3.369
# 🧬 Evolution G62: 61 mutations, improvement: 0.0036
# [MADDPG-EVO-DGM] Epoch 920/1000: reward=119.382, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-3.7866, critic_loss=1.8582, avg_q=3.389
# [MADDPG-EVO-DGM] Epoch 930/1000: reward=119.579, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-3.8410, critic_loss=1.8908, avg_q=3.381
# 🧬 Evolution G63: 61 mutations, improvement: 0.0032
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 940/1000: reward=118.924, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-3.8611, critic_loss=2.2065, avg_q=3.414
# 🧬 Evolution G64: 61 mutations, improvement: 0.0034
# [MADDPG-EVO-DGM] Epoch 950/1000: reward=119.054, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-3.8759, critic_loss=1.9901, avg_q=3.410
# [MADDPG-EVO-DGM] Epoch 960/1000: reward=118.015, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-3.8468, critic_loss=2.3847, avg_q=3.417
# 🧬 Evolution G65: 61 mutations, improvement: 0.0042
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 970/1000: reward=117.565, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-3.8938, critic_loss=2.4781, avg_q=3.442
# 🧬 Evolution G66: 61 mutations, improvement: 0.0035
# [MADDPG-EVO-DGM] Epoch 980/1000: reward=118.147, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-3.9261, critic_loss=2.3332, avg_q=3.473
# [MADDPG-EVO-DGM] Epoch 990/1000: reward=116.579, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-3.9400, critic_loss=2.4637, avg_q=3.453
# 🧬 Evolution G67: 61 mutations, improvement: 0.0028
# 🔧 DGM: Architecture changes: 2
# [MADDPG-EVO-DGM] Epoch 1000/1000: reward=117.253, regions=86, noise=0.050
#   📊 Metrics: actor_loss=-3.9517, critic_loss=2.3073, avg_q=3.486
# 🧪 TESTING PHASE (200 epochs)
# MADDPG-EVO-DGM Testing:   0%|          | 0/200 [00:00<?, ?it/s]
# ✅ MADDPG-EVO-DGM - TRAINING COMPLETED:
#   📊 Final reward: 116.9160
#   📈 Maximum reward: 139.5924
#   📊 Overall improvement: 105.5131
#   🧪 Test reward: 117.8508
#   🧪 Max in test: 120.8563
#   📊 Stability: 1.008
#   🤖 Trained agents: 86
#   💾 Total experience: 920415
# 🎨 CREATING VISUALIZATION
# ==================================================
# 📈 Training curves plot...
# 📊 Results table...
#      Algorithm  Final Reward  Maximum Reward  Standard Deviation  Improvement  Stability  Training Epochs  Test Reward  Generalization  Testing Epochs
#         MADDPG       91.7569        126.2302           30.534361      80.6447   2.129036             1000      92.6754        1.010010             200
#     MADDPG-EVO       67.8096        114.0592           25.506441      53.3424   2.073894             1000      67.9187        1.001610             200
# MADDPG-EVO-DGM      116.9160        139.5924           37.440461     105.5131   2.313470             1000     117.8508        1.007995             200
# 🏆 Final comparison...
# 🎯 ALGORITHM EVALUATION:
# --------------------------------------------------
# 🥇 MADDPG-EVO-DGM: 116.9160
# 🥈 MADDPG: 91.7569
# 🥉 MADDPG-EVO: 67.8096
# MADDPG Score: 91.75687582123396
# MADDPG-EVO Score: 67.8095721390864
# MADDPG-EVO-DGM Score: 116.91596222434202
# 🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆
# TRAINING RESULTS
# 🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆
# 🎉 FULL EXPERIMENT COMPLETED!
# 📊 Graphs and tables created
# 🔬 algorithm comparison completed
